# %% [markdown]
# # Aggregating Hazard Ratios of Cox Models for All Infections

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
warnings.warn('DelftStack')
warnings.warn('Do not show this message')

# %%
hrs_lrti_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_lrti/hazard_ratios_betas_cph_lrti_no_abs_incdt.csv')
hrs_lrti_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_lrti/hazard_ratios_betas_cph_lrti_abs_incdt.csv')
hrs_lrti_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_lrti/hazard_ratios_betas_cph_lrti_no_abs_prevl.csv')
hrs_lrti_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_lrti/hazard_ratios_betas_cph_lrti_abs_prevl.csv')
betas_lrti_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_lrti/betas_cph_lrti_no_abs_incdt.csv')
betas_lrti_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_lrti/betas_cph_lrti_abs_incdt.csv')
betas_lrti_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_lrti/betas_cph_lrti_no_abs_prevl.csv')
betas_lrti_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_lrti/betas_cph_lrti_abs_prevl.csv')

hrs_urti_combined_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/hazard_ratios_betas_cph_urti_combined_no_abs_incdt.csv')
hrs_urti_combined_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/hazard_ratios_betas_cph_urti_combined_abs_incdt.csv')
hrs_urti_combined_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/hazard_ratios_betas_cph_urti_combined_no_abs_prevl.csv')
hrs_urti_combined_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/hazard_ratios_betas_cph_urti_combined_abs_prevl.csv')
betas_urti_combined_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/betas_cph_urti_combined_no_abs_incdt.csv')
betas_urti_combined_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/betas_cph_urti_combined_abs_incdt.csv')
betas_urti_combined_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/betas_cph_urti_combined_no_abs_prevl.csv')
betas_urti_combined_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/betas_cph_urti_combined_abs_prevl.csv')

hrs_uti_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_uti/hazard_ratios_betas_cph_uti_no_abs_incdt.csv')
hrs_uti_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_uti/hazard_ratios_betas_cph_uti_abs_incdt.csv')
hrs_uti_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_uti/hazard_ratios_betas_cph_uti_no_abs_prevl.csv')
hrs_uti_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_uti/hazard_ratios_betas_cph_uti_abs_prevl.csv')
betas_uti_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_uti/betas_cph_uti_no_abs_incdt.csv')
betas_uti_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_uti/betas_cph_uti_abs_incdt.csv')
betas_uti_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_uti/betas_cph_uti_no_abs_prevl.csv')
betas_uti_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_uti/betas_cph_uti_abs_prevl.csv')

hrs_sinusitis_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/hazard_ratios_betas_cph_sinusitis_no_abs_incdt.csv')
# hrs_sinusitis_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/hazard_ratios_betas_cph_sinusitis_abs_incdt.csv')
hrs_sinusitis_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/hazard_ratios_betas_cph_sinusitis_no_abs_prevl.csv')
# hrs_sinusitis_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/hazard_ratios_betas_cph_sinusitis_abs_prevl.csv')
betas_sinusitis_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/betas_cph_sinusitis_no_abs_incdt.csv')
# betas_sinusitis_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/betas_cph_sinusitis_abs_incdt.csv')
betas_sinusitis_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/betas_cph_sinusitis_no_abs_prevl.csv')
# betas_sinusitis_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/betas_cph_sinusitis_abs_prevl.csv')

hrs_otmedia_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/hazard_ratios_betas_cph_otmedia_no_abs_incdt.csv')
hrs_otmedia_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/hazard_ratios_betas_cph_otmedia_abs_incdt.csv')
hrs_otmedia_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/hazard_ratios_betas_cph_otmedia_no_abs_prevl.csv')
hrs_otmedia_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/hazard_ratios_betas_cph_otmedia_abs_prevl.csv')
betas_otmedia_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/betas_cph_otmedia_no_abs_incdt.csv')
betas_otmedia_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/betas_cph_otmedia_abs_incdt.csv')
betas_otmedia_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/betas_cph_otmedia_no_abs_prevl.csv')
betas_otmedia_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/betas_cph_otmedia_abs_prevl.csv')

hrs_ot_externa_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/hazard_ratios_betas_cph_ot_externa_no_abs_incdt.csv')
hrs_ot_externa_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/hazard_ratios_betas_cph_ot_externa_abs_incdt.csv')
hrs_ot_externa_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/hazard_ratios_betas_cph_ot_externa_no_abs_prevl.csv')
hrs_ot_externa_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/hazard_ratios_betas_cph_ot_externa_abs_prevl.csv')
betas_ot_externa_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/betas_cph_ot_externa_no_abs_incdt.csv')
betas_ot_externa_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/betas_cph_ot_externa_abs_incdt.csv')
betas_ot_externa_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/betas_cph_ot_externa_no_abs_prevl.csv')
betas_ot_externa_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/betas_cph_ot_externa_abs_prevl.csv')

hrs_pneumonia_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/hazard_ratios_betas_cph_pneumonia_no_abs_incdt.csv')
hrs_pneumonia_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/hazard_ratios_betas_cph_pneumonia_abs_incdt.csv')
hrs_pneumonia_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/hazard_ratios_betas_cph_pneumonia_no_abs_prevl.csv')
hrs_pneumonia_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/hazard_ratios_betas_cph_pneumonia_abs_prevl.csv')
betas_pneumonia_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/betas_cph_pneumonia_no_abs_incdt.csv')
betas_pneumonia_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/betas_cph_pneumonia_abs_incdt.csv')
betas_pneumonia_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/betas_cph_pneumonia_no_abs_prevl.csv')
betas_pneumonia_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/betas_cph_pneumonia_abs_prevl.csv')

hrs_urti_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_urti/hazard_ratios_betas_cph_urti_no_abs_incdt.csv')
hrs_urti_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_urti/hazard_ratios_betas_cph_urti_abs_incdt.csv')
hrs_urti_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_urti/hazard_ratios_betas_cph_urti_no_abs_prevl.csv')
hrs_urti_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_urti/hazard_ratios_betas_cph_urti_abs_prevl.csv')
betas_urti_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_urti/betas_cph_urti_no_abs_incdt.csv')
betas_urti_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_urti/betas_cph_urti_abs_incdt.csv')
betas_urti_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_urti/betas_cph_urti_no_abs_prevl.csv')
betas_urti_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_urti/betas_cph_urti_abs_prevl.csv')

hrs_cough_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_cough/hazard_ratios_betas_cph_cough_no_abs_incdt.csv')
hrs_cough_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_cough/hazard_ratios_betas_cph_cough_abs_incdt.csv')
hrs_cough_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_cough/hazard_ratios_betas_cph_cough_no_abs_prevl.csv')
hrs_cough_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_cough/hazard_ratios_betas_cph_cough_abs_prevl.csv')
betas_cough_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_cough/betas_cph_cough_no_abs_incdt.csv')
betas_cough_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_cough/betas_cph_cough_abs_incdt.csv')
betas_cough_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_cough/betas_cph_cough_no_abs_prevl.csv')
betas_cough_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_cough/betas_cph_cough_abs_prevl.csv')

hrs_cough_cold_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/hazard_ratios_betas_cph_cough_cold_no_abs_incdt.csv')
hrs_cough_cold_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/hazard_ratios_betas_cph_cough_cold_abs_incdt.csv')
hrs_cough_cold_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/hazard_ratios_betas_cph_cough_cold_no_abs_prevl.csv')
hrs_cough_cold_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/hazard_ratios_betas_cph_cough_cold_abs_prevl.csv')
betas_cough_cold_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/betas_cph_cough_cold_no_abs_incdt.csv')
betas_cough_cold_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/betas_cph_cough_cold_abs_incdt.csv')
betas_cough_cold_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/betas_cph_cough_cold_no_abs_prevl.csv')
betas_cough_cold_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/betas_cph_cough_cold_abs_prevl.csv')

hrs_throat_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_throat/hazard_ratios_betas_cph_throat_no_abs_incdt.csv')
hrs_throat_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_throat/hazard_ratios_betas_cph_throat_abs_incdt.csv')
hrs_throat_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_throat/hazard_ratios_betas_cph_throat_no_abs_prevl.csv')
hrs_throat_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_throat/hazard_ratios_betas_cph_throat_abs_prevl.csv')
betas_throat_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_throat/betas_cph_throat_no_abs_incdt.csv')
betas_throat_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_throat/betas_cph_throat_abs_incdt.csv')
betas_throat_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_throat/betas_cph_throat_no_abs_prevl.csv')
betas_throat_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_throat/betas_cph_throat_abs_prevl.csv')

# %%
def data_process_hrs(data):
    data_hrs = data
    data_hrs['exp(coef)'] = np.round(data_hrs['exp(coef)'], decimals=2)
    data_hrs['95% lower-bound'] = np.round(data_hrs['95% lower-bound'], decimals=2)
    data_hrs['95% upper-bound'] = np.round(data_hrs['95% upper-bound'], decimals=2)
    data_hrs['betas'] = data_hrs['exp(coef)'].astype(str) + " (" + data_hrs['95% lower-bound'].astype(str) + '--' + data_hrs['95% upper-bound'].astype(str) + ')'
    
    return data_hrs

# %%
cph_lrti_no_abs_incdt_hrs = data_process_hrs(hrs_lrti_no_abs_incdt)
cph_lrti_no_abs_prevl_hrs = data_process_hrs(hrs_lrti_no_abs_prevl)
cph_lrti_abs_incdt_hrs = data_process_hrs(hrs_lrti_abs_incdt)
cph_lrti_abs_prevl_hrs = data_process_hrs(hrs_lrti_abs_prevl)

cph_urti_combined_no_abs_incdt_hrs = data_process_hrs(hrs_urti_combined_no_abs_incdt)
cph_urti_combined_no_abs_prevl_hrs = data_process_hrs(hrs_urti_combined_no_abs_prevl)
cph_urti_combined_abs_incdt_hrs = data_process_hrs(hrs_urti_combined_abs_incdt)
cph_urti_combined_abs_prevl_hrs = data_process_hrs(hrs_urti_combined_abs_prevl)

cph_uti_no_abs_incdt_hrs = data_process_hrs(hrs_uti_no_abs_incdt)
cph_uti_no_abs_prevl_hrs = data_process_hrs(hrs_uti_no_abs_prevl)
cph_uti_abs_incdt_hrs = data_process_hrs(hrs_uti_abs_incdt)
cph_uti_abs_prevl_hrs = data_process_hrs(hrs_uti_abs_prevl)

cph_sinusitis_no_abs_incdt_hrs = data_process_hrs(hrs_sinusitis_no_abs_incdt)
cph_sinusitis_no_abs_prevl_hrs = data_process_hrs(hrs_sinusitis_no_abs_prevl)
# cph_sinusitis_abs_incdt_hrs = data_process_hrs(hrs_sinusitis_abs_incdt)
# cph_sinusitis_abs_prevl_hrs = data_process_hrs(hrs_sinusitis_abs_prevl)

cph_otmedia_no_abs_incdt_hrs = data_process_hrs(hrs_otmedia_no_abs_incdt)
cph_otmedia_no_abs_prevl_hrs = data_process_hrs(hrs_otmedia_no_abs_prevl)
cph_otmedia_abs_incdt_hrs = data_process_hrs(hrs_otmedia_abs_incdt)
cph_otmedia_abs_prevl_hrs = data_process_hrs(hrs_otmedia_abs_prevl)

cph_ot_externa_no_abs_incdt_hrs = data_process_hrs(hrs_ot_externa_no_abs_incdt)
cph_ot_externa_no_abs_prevl_hrs = data_process_hrs(hrs_ot_externa_no_abs_prevl)
cph_ot_externa_abs_incdt_hrs = data_process_hrs(hrs_ot_externa_abs_incdt)
cph_ot_externa_abs_prevl_hrs = data_process_hrs(hrs_ot_externa_abs_prevl)

cph_pneumonia_no_abs_incdt_hrs = data_process_hrs(hrs_pneumonia_no_abs_incdt)
cph_pneumonia_no_abs_prevl_hrs = data_process_hrs(hrs_pneumonia_no_abs_prevl)
cph_pneumonia_abs_incdt_hrs = data_process_hrs(hrs_pneumonia_abs_incdt)
cph_pneumonia_abs_prevl_hrs = data_process_hrs(hrs_pneumonia_abs_prevl)

cph_urti_no_abs_incdt_hrs = data_process_hrs(hrs_urti_no_abs_incdt)
cph_urti_no_abs_prevl_hrs = data_process_hrs(hrs_urti_no_abs_prevl)
cph_urti_abs_incdt_hrs = data_process_hrs(hrs_urti_abs_incdt)
cph_urti_abs_prevl_hrs = data_process_hrs(hrs_urti_abs_prevl)

cph_cough_no_abs_incdt_hrs = data_process_hrs(hrs_cough_no_abs_incdt)
cph_cough_no_abs_prevl_hrs = data_process_hrs(hrs_cough_no_abs_prevl)
cph_cough_abs_incdt_hrs = data_process_hrs(hrs_cough_abs_incdt)
cph_cough_abs_prevl_hrs = data_process_hrs(hrs_cough_abs_prevl)

cph_cough_cold_no_abs_incdt_hrs = data_process_hrs(hrs_cough_cold_no_abs_incdt)
cph_cough_cold_no_abs_prevl_hrs = data_process_hrs(hrs_cough_cold_no_abs_prevl)
cph_cough_cold_abs_incdt_hrs = data_process_hrs(hrs_cough_cold_abs_incdt)
cph_cough_cold_abs_prevl_hrs = data_process_hrs(hrs_cough_cold_abs_prevl)

cph_throat_no_abs_incdt_hrs = data_process_hrs(hrs_throat_no_abs_incdt)
cph_throat_no_abs_prevl_hrs = data_process_hrs(hrs_throat_no_abs_prevl)
cph_throat_abs_incdt_hrs = data_process_hrs(hrs_throat_abs_incdt)
cph_throat_abs_prevl_hrs = data_process_hrs(hrs_throat_abs_prevl)

# %%
d = {'variable': cph_lrti_no_abs_incdt_hrs['covariate'],
     
     'lrti_no_abs_incdt': cph_lrti_no_abs_incdt_hrs['betas'], 
     'lrti_abs_incdt': cph_lrti_abs_incdt_hrs['betas'],
     'lrti_no_abs_prevl': cph_lrti_no_abs_prevl_hrs['betas'], 
     'lrti_abs_prevl': cph_lrti_abs_prevl_hrs['betas'],
     
     'urti_combined_no_abs_incdt': cph_urti_combined_no_abs_incdt_hrs['betas'], 
     'urti_combined_abs_incdt': cph_urti_combined_abs_incdt_hrs['betas'],
     'urti_combined_no_abs_prevl': cph_urti_combined_no_abs_prevl_hrs['betas'], 
     'urti_combined_abs_prevl': cph_urti_combined_abs_prevl_hrs['betas'],
     
     'uti_no_abs_incdt': cph_uti_no_abs_incdt_hrs['betas'], 
     'uti_abs_incdt': cph_uti_abs_incdt_hrs['betas'],
     'uti_no_abs_prevl': cph_uti_no_abs_prevl_hrs['betas'], 
     'uti_abs_prevl': cph_uti_abs_prevl_hrs['betas'],
     
     'sinusitis_no_abs_incdt': cph_sinusitis_no_abs_incdt_hrs['betas'], 
    #  'sinusitis_abs_incdt': cph_sinusitis_abs_incdt_hrs['betas'],
     'sinusitis_no_abs_prevl': cph_sinusitis_no_abs_prevl_hrs['betas'], 
    #  'sinusitis_abs_prevl': cph_sinusitis_abs_prevl_hrs['betas'],
     
     'otmedia_no_abs_incdt': cph_otmedia_no_abs_incdt_hrs['betas'], 
     'otmedia_abs_incdt': cph_otmedia_abs_incdt_hrs['betas'],
     'otmedia_no_abs_prevl': cph_otmedia_no_abs_prevl_hrs['betas'], 
     'otmedia_abs_prevl': cph_otmedia_abs_prevl_hrs['betas'],
     
     'ot_externa_no_abs_incdt': cph_ot_externa_no_abs_incdt_hrs['betas'], 
     'ot_externa_abs_incdt': cph_ot_externa_abs_incdt_hrs['betas'],
     'ot_externa_no_abs_prevl': cph_ot_externa_no_abs_prevl_hrs['betas'], 
     'ot_externa_abs_prevl': cph_ot_externa_abs_prevl_hrs['betas'],

     'pneumonia_no_abs_incdt': cph_pneumonia_no_abs_incdt_hrs['betas'], 
     'pneumonia_abs_incdt': cph_pneumonia_abs_incdt_hrs['betas'],
     'pneumonia_no_abs_prevl': cph_pneumonia_no_abs_prevl_hrs['betas'], 
     'pneumonia_abs_prevl': cph_pneumonia_abs_prevl_hrs['betas'],

     'urti_no_abs_incdt': cph_urti_no_abs_incdt_hrs['betas'], 
     'urti_abs_incdt': cph_urti_abs_incdt_hrs['betas'],
     'urti_no_abs_prevl': cph_urti_no_abs_prevl_hrs['betas'], 
     'urti_abs_prevl': cph_urti_abs_prevl_hrs['betas'],

     'cough_no_abs_incdt': cph_cough_no_abs_incdt_hrs['betas'], 
     'cough_abs_incdt': cph_cough_abs_incdt_hrs['betas'],
     'cough_no_abs_prevl': cph_cough_no_abs_prevl_hrs['betas'], 
     'cough_abs_prevl': cph_cough_abs_prevl_hrs['betas'],

     'cough_cold_no_abs_incdt': cph_cough_cold_no_abs_incdt_hrs['betas'], 
     'cough_cold_abs_incdt': cph_cough_cold_abs_incdt_hrs['betas'],
     'cough_cold_no_abs_prevl': cph_cough_cold_no_abs_prevl_hrs['betas'], 
     'cough_cold_abs_prevl': cph_cough_cold_abs_prevl_hrs['betas'],

     'throat_no_abs_incdt': cph_throat_no_abs_incdt_hrs['betas'], 
     'throat_abs_incdt': cph_throat_abs_incdt_hrs['betas'],
     'throat_no_abs_prevl': cph_throat_no_abs_prevl_hrs['betas'], 
     'throat_abs_prevl': cph_throat_abs_prevl_hrs['betas'],
    }
data = pd.DataFrame(data=d)

#custom order of variables to fit tables of the manuscript again
data['variable'] = pd.Categorical(data['variable'], ['sex_male', 'age_cat_25_34', 'age_cat_35_44', 'age_cat_45_54', 'age_cat_55_64', 'age_cat_65_74', 'age_cat_75_more', 'bmi_cat_underweight', 'bmi_cat_overweight', 'bmi_cat_obese', 'bmi_cat_unknown', 'ethnicity_white', 'ethnicity_unknown', 'CCI_cat_low', 'CCI_cat_medium', 'CCI_cat_high', 'CCI_cat_very_high', 'smoking_status_smoker', 'smoking_status_never_smoked', 'smoking_status_unknown', 'imd_very_affluent', 'imd_medium', 'imd_unaffluent', 'imd_very_unaffluent', 'imd_unknown', 'season_spring', 'season_summer', 'season_winter', 'region_london', 'region_north_east', 'region_north_west', 'region_west_midlands', 'region_yorkshire', 'region_south_east', 'region_east_midlands', 'region_south_west', 'flu_vaccine_yes', 'antibacterial_brit'])
data = data.sort_values('variable')

#print output in csv
data.to_csv(f'../output/aggregate_hrs_betas/cph_hrs_all_infections.csv', index=False)
data
# Out:
#                        variable   lrti_no_abs_incdt       lrti_abs_incdt  \
# 34                     sex_male  0.95 (-0.19--0.09)   0.77 (-0.65--0.13)
# 4                 age_cat_25_34  1.19 (-0.08--0.43)    3.25 (0.17--2.19)
# 5                 age_cat_35_44   1.06 (-0.2--0.32)    3.23 (0.17--2.18)
# 6                 age_cat_45_54  0.91 (-0.37--0.18)     4.01 (0.4--2.38)
# 7                 age_cat_55_64   1.1 (-0.17--0.35)    3.19 (0.16--2.16)
# 8                 age_cat_65_74   1.06 (-0.2--0.32)     3.2 (0.16--2.17)
# 9               age_cat_75_more  0.96 (-0.31--0.23)    3.01 (0.09--2.12)
# 13          bmi_cat_underweight  0.82 (-0.69--0.29)   0.75 (-1.84--1.27)
# 12           bmi_cat_overweight  0.91 (-0.42--0.22)    1.39 (-0.54--1.2)
# 11                bmi_cat_obese   1.0 (-0.26--0.26)   1.32 (-0.46--1.01)
# 14              bmi_cat_unknown  0.97 (-0.31--0.25)    0.89 (-0.94--0.7)
# 16              ethnicity_white  0.89 (-0.31--0.07)    0.7 (-0.84--0.13)
# ...

# %%
d = {'variable': betas_lrti_no_abs_incdt['covariate'],
     
     'lrti_no_abs_incdt': betas_lrti_no_abs_incdt['coef'],
     'lrti_no_abs_prevl': betas_lrti_no_abs_prevl['coef'],
     
     'urti_combined_no_abs_incdt': betas_urti_combined_no_abs_incdt['coef'],
     'urti_combined_no_abs_prevl': betas_urti_combined_no_abs_prevl['coef'],
     
     'uti_no_abs_incdt': betas_uti_no_abs_incdt['coef'],
     'uti_no_abs_prevl': betas_uti_no_abs_prevl['coef'],
     
     'sinusitis_no_abs_incdt': betas_sinusitis_no_abs_incdt['coef'],
     'sinusitis_no_abs_prevl': betas_sinusitis_no_abs_prevl['coef'],
     
     'otmedia_no_abs_incdt': betas_otmedia_no_abs_incdt['coef'],
     'otmedia_no_abs_prevl': betas_otmedia_no_abs_prevl['coef'],
     
     'ot_externa_no_abs_incdt': betas_ot_externa_no_abs_incdt['coef'],
     'ot_externa_no_abs_prevl': betas_ot_externa_no_abs_prevl['coef'],
    
     'pneumonia_no_abs_incdt': betas_pneumonia_no_abs_incdt['coef'],
     'pneumonia_abs_prevl': betas_pneumonia_abs_prevl['coef'],

     'urti_no_abs_incdt': betas_urti_no_abs_incdt['coef'],
     'urti_no_abs_prevl': betas_urti_no_abs_prevl['coef'],

     'cough_no_abs_incdt': betas_cough_no_abs_incdt['coef'],
     'cough_no_abs_prevl': betas_cough_no_abs_prevl['coef'],

     'cough_cold_no_abs_incdt': betas_cough_cold_no_abs_incdt['coef'],
     'cough_cold_no_abs_prevl': betas_cough_cold_no_abs_prevl['coef'],

     'throat_no_abs_incdt': betas_throat_no_abs_incdt['coef'],
     'throat_no_abs_prevl': betas_throat_no_abs_prevl['coef'],
    }
data = pd.DataFrame(data=d)

#print output in csv
data.to_csv(f'../output/aggregate_hrs_betas/cph_betas_all_infections.csv', index=False)
data
# Out:
#                        variable  lrti_no_abs_incdt  lrti_no_abs_prevl  \
# 0                   CCI_cat_low          -0.003261          -0.425037
# 1                CCI_cat_medium          -0.120133          -0.189846
# 2                  CCI_cat_high          -0.001769           0.207760
# 3             CCI_cat_very_high          -0.125612          -0.268876
# 4                 age_cat_25_34           0.174959          -0.365500
# 5                 age_cat_35_44           0.060240           0.631900
# 6                 age_cat_45_54          -0.094081           0.416342
# 7                 age_cat_55_64           0.090949           0.010490
# 8                 age_cat_65_74           0.061322           0.417773
# 9               age_cat_75_more          -0.038712           0.418480
# 10           antibacterial_brit          -0.000706           0.066807
# 11                bmi_cat_obese           0.004036           0.039446
# ...
