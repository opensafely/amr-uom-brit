# %% [markdown]
# # Aggregating Hazard Ratios of Cox Models for All Infections

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
warnings.warn('DelftStack')
warnings.warn('Do not show this message')

# %%
cph_lrti_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_no_abs_incdt_summary.html')
cph_lrti_no_abs_incdt_1 = cph_lrti_no_abs_incdt[1]

# %%
cph_lrti_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_abs_incdt_summary.html')
cph_lrti_abs_incdt_1 = cph_lrti_abs_incdt[1]

# %%
cph_lrti_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_no_abs_prevl_summary.html')
cph_lrti_no_abs_prevl_1 = cph_lrti_no_abs_incdt[1]

# %%
cph_lrti_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_abs_prevl_summary.html')
cph_lrti_abs_prevl_1 = cph_lrti_abs_prevl[1]

# %%
cph_urti_combined_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_no_abs_incdt_summary.html')
cph_urti_combined_no_abs_incdt_1 = cph_urti_combined_no_abs_incdt[1]
cph_urti_combined_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_abs_incdt_summary.html')
cph_urti_combined_abs_incdt_1 = cph_urti_combined_abs_incdt[1]
cph_urti_combined_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_no_abs_prevl_summary.html')
cph_urti_combined_no_abs_prevl_1 = cph_urti_combined_no_abs_prevl[1]
cph_urti_combined_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_abs_prevl_summary.html')
cph_urti_combined_abs_prevl_1 = cph_urti_combined_abs_prevl[1]

cph_uti_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_no_abs_incdt_summary.html')
cph_uti_no_abs_incdt_1 = cph_uti_no_abs_incdt[1]
cph_uti_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_abs_incdt_summary.html')
cph_uti_abs_incdt_1 = cph_uti_abs_incdt[1]
cph_uti_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_no_abs_prevl_summary.html')
cph_uti_no_abs_prevl_1 = cph_uti_no_abs_prevl[1]
cph_uti_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_abs_prevl_summary.html')
cph_uti_abs_prevl_1 = cph_uti_abs_prevl[1]

cph_sinusitis_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_no_abs_incdt_summary.html')
cph_sinusitis_no_abs_incdt_1 = cph_sinusitis_no_abs_incdt[1]
cph_sinusitis_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_abs_incdt_summary.html')
cph_sinusitis_abs_incdt_1 = cph_sinusitis_abs_incdt[1]
# cph_sinusitis_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_no_abs_prevl_summary.html')
# cph_sinusitis_no_abs_prevl_1 = cph_sinusitis_no_abs_prevl[1]
# cph_sinusitis_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_abs_prevl_summary.html')
# cph_sinusitis_abs_prevl_1 = cph_sinusitis_abs_prevl[1]

cph_otmedia_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_no_abs_incdt_summary.html')
cph_otmedia_no_abs_incdt_1 = cph_otmedia_no_abs_incdt[1]
cph_otmedia_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_abs_incdt_summary.html')
cph_otmedia_abs_incdt_1 = cph_otmedia_abs_incdt[1]
cph_otmedia_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_no_abs_prevl_summary.html')
cph_otmedia_no_abs_prevl_1 = cph_otmedia_no_abs_prevl[1]
cph_otmedia_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_abs_prevl_summary.html')
cph_otmedia_abs_prevl_1 = cph_otmedia_abs_prevl[1]

cph_ot_externa_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_no_abs_incdt_summary.html')
cph_ot_externa_no_abs_incdt_1 = cph_ot_externa_no_abs_incdt[1]
cph_ot_externa_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_abs_incdt_summary.html')
cph_ot_externa_abs_incdt_1 = cph_ot_externa_abs_incdt[1]
cph_ot_externa_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_no_abs_prevl_summary.html')
cph_ot_externa_no_abs_prevl_1 = cph_ot_externa_no_abs_prevl[1]
# cph_ot_externa_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_abs_prevl_summary.html')
# cph_ot_externa_abs_prevl_1 = cph_ot_externa_abs_prevl[1]

cph_pneumonia_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_no_abs_incdt_summary.html')
cph_pneumonia_no_abs_incdt_1 = cph_pneumonia_no_abs_incdt[1]
cph_pneumonia_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_abs_incdt_summary.html')
cph_pneumonia_abs_incdt_1 = cph_pneumonia_abs_incdt[1]
cph_pneumonia_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_no_abs_prevl_summary.html')
cph_pneumonia_no_abs_prevl_1 = cph_pneumonia_no_abs_prevl[1]
# cph_pneumonia_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_abs_prevl_summary.html')
# cph_pneumonia_abs_prevl_1 = cph_pneumonia_abs_prevl[1]

cph_urti_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_no_abs_incdt_summary.html')
cph_urti_no_abs_incdt_1 = cph_urti_no_abs_incdt[1]
cph_urti_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_abs_incdt_summary.html')
cph_urti_abs_incdt_1 = cph_urti_abs_incdt[1]
cph_urti_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_no_abs_prevl_summary.html')
cph_urti_no_abs_prevl_1 = cph_urti_no_abs_prevl[1]
cph_urti_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_abs_prevl_summary.html')
cph_urti_abs_prevl_1 = cph_urti_abs_prevl[1]

cph_cough_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_no_abs_incdt_summary.html')
cph_cough_no_abs_incdt_1 = cph_cough_no_abs_incdt[1]
cph_cough_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_abs_incdt_summary.html')
cph_cough_abs_incdt_1 = cph_cough_abs_incdt[1]
cph_cough_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_no_abs_prevl_summary.html')
cph_cough_no_abs_prevl_1 = cph_cough_no_abs_prevl[1]
cph_cough_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_abs_prevl_summary.html')
cph_cough_abs_prevl_1 = cph_cough_abs_prevl[1]

cph_cough_cold_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_no_abs_incdt_summary.html')
cph_cough_cold_no_abs_incdt_1 = cph_cough_cold_no_abs_incdt[1]
cph_cough_cold_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_abs_incdt_summary.html')
cph_cough_cold_abs_incdt_1 = cph_cough_cold_abs_incdt[1]
cph_cough_cold_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_no_abs_prevl_summary.html')
cph_cough_cold_no_abs_prevl_1 = cph_cough_cold_no_abs_prevl[1]
cph_cough_cold_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_abs_prevl_summary.html')
cph_cough_cold_abs_prevl_1 = cph_cough_cold_abs_prevl[1]

cph_throat_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_no_abs_incdt_summary.html')
cph_throat_no_abs_incdt_1 = cph_throat_no_abs_incdt[1]
cph_throat_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_abs_incdt_summary.html')
cph_throat_abs_incdt_1 = cph_throat_abs_incdt[1]
cph_throat_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_no_abs_prevl_summary.html')
cph_throat_no_abs_prevl_1 = cph_throat_no_abs_prevl[1]
cph_throat_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_abs_prevl_summary.html')
cph_throat_abs_prevl_1 = cph_throat_abs_prevl[1]

# %%
def data_process_hrs_betas(data):
    data.columns = ['variable', 'coef', 'exp(coef)', 'se(coef)', 'coef lower 95%', 'coef upper 95%', 'exp(coef) lower 95%', 'exp(coef) upper 95%', 'cmp to', 'z', 'p', '-log2(p)']
    data_hrs = data[['variable', 'exp(coef)', 'exp(coef) lower 95%', 'exp(coef) upper 95%']]
    data_hrs['exp(coef)'] = data_hrs['exp(coef)'].apply(lambda x: "{:.2f}".format(x))
    data_hrs['exp(coef) lower 95%'] = data_hrs['exp(coef) lower 95%'].apply(lambda x: "{:.2f}".format(x))
    data_hrs['exp(coef) upper 95%'] = data_hrs['exp(coef) upper 95%'].apply(lambda x: "{:.2f}".format(x))
    data_hrs['betas'] = data_hrs['exp(coef)'].astype(str) + " (" + data['exp(coef) lower 95%'].apply(lambda x: "{:.2f}".format(x)).astype(str) + '-' + data['exp(coef) upper 95%'].apply(lambda x: "{:.2f}".format(x)).astype(str) + ')'
    
    data_hrs = data_hrs.sort_values('variable')
    data_hrs = data_hrs[['variable', 'betas']]
    
    data_betas = data[['variable', 'coef']]
    
    return data_hrs, data_betas

# %%
cph_lrti_no_abs_incdt_hrs, cph_lrti_no_abs_incdt_betas = data_process_hrs_betas(cph_lrti_no_abs_incdt_1)
cph_lrti_no_abs_prevl_hrs, cph_lrti_no_abs_prevl_betas = data_process_hrs_betas(cph_lrti_no_abs_prevl_1)
cph_lrti_abs_incdt_hrs, cph_lrti_abs_incdt_betas = data_process_hrs_betas(cph_lrti_abs_incdt_1)
cph_lrti_abs_prevl_hrs, cph_lrti_abs_prevl_betas = data_process_hrs_betas(cph_lrti_abs_prevl_1)

# %%
cph_urti_combined_no_abs_incdt_hrs, cph_urti_combined_no_abs_incdt_betas = data_process_hrs_betas(cph_urti_combined_no_abs_incdt_1)
cph_urti_combined_no_abs_prevl_hrs, cph_urti_combined_no_abs_prevl_betas = data_process_hrs_betas(cph_urti_combined_no_abs_prevl_1)
cph_urti_combined_abs_incdt_hrs, cph_urti_combined_abs_incdt_betas = data_process_hrs_betas(cph_urti_combined_abs_incdt_1)
cph_urti_combined_abs_prevl_hrs, cph_urti_combined_abs_prevl_betas = data_process_hrs_betas(cph_urti_combined_abs_prevl_1)

# %%
cph_uti_no_abs_incdt_hrs, cph_uti_no_abs_incdt_betas = data_process_hrs_betas(cph_uti_no_abs_incdt_1)
cph_uti_no_abs_prevl_hrs, cph_uti_no_abs_prevl_betas = data_process_hrs_betas(cph_uti_no_abs_prevl_1)
cph_uti_abs_incdt_hrs, cph_uti_abs_incdt_betas = data_process_hrs_betas(cph_uti_abs_incdt_1)
cph_uti_abs_prevl_hrs, cph_uti_abs_prevl_betas = data_process_hrs_betas(cph_uti_abs_prevl_1)

# %%
cph_sinusitis_no_abs_incdt_hrs, cph_sinusitis_no_abs_incdt_betas = data_process_hrs_betas(cph_sinusitis_no_abs_incdt_1)
# cph_sinusitis_no_abs_prevl_hrs, cph_sinusitis_no_abs_prevl_betas = data_process_hrs_betas(cph_sinusitis_no_abs_prevl_1)
cph_sinusitis_abs_incdt_hrs, cph_sinusitis_abs_incdt_betas = data_process_hrs_betas(cph_sinusitis_abs_incdt_1)
# cph_sinusitis_abs_prevl_hrs, cph_sinusitis_abs_prevl_betas = data_process_hrs_betas(cph_sinusitis_abs_prevl_1)

# %%
cph_otmedia_no_abs_incdt_hrs, cph_otmedia_no_abs_incdt_betas = data_process_hrs_betas(cph_otmedia_no_abs_incdt_1)
cph_otmedia_no_abs_prevl_hrs, cph_otmedia_no_abs_prevl_betas = data_process_hrs_betas(cph_otmedia_no_abs_prevl_1)
cph_otmedia_abs_incdt_hrs, cph_otmedia_abs_incdt_betas = data_process_hrs_betas(cph_otmedia_abs_incdt_1)
cph_otmedia_abs_prevl_hrs, cph_otmedia_abs_prevl_betas = data_process_hrs_betas(cph_otmedia_abs_prevl_1)

# %%
cph_ot_externa_no_abs_incdt_hrs, cph_ot_externa_no_abs_incdt_betas = data_process_hrs_betas(cph_ot_externa_no_abs_incdt_1)
cph_ot_externa_no_abs_prevl_hrs, cph_ot_externa_no_abs_prevl_betas = data_process_hrs_betas(cph_ot_externa_no_abs_prevl_1)
cph_ot_externa_abs_incdt_hrs, cph_ot_externa_abs_incdt_betas = data_process_hrs_betas(cph_ot_externa_abs_incdt_1)
# cph_ot_externa_abs_prevl_hrs, cph_ot_externa_abs_prevl_betas = data_process_hrs_betas(cph_ot_externa_abs_prevl_1)

# %%
cph_pneumonia_no_abs_incdt_hrs, cph_pneumonia_no_abs_incdt_betas = data_process_hrs_betas(cph_pneumonia_no_abs_incdt_1)
cph_pneumonia_no_abs_prevl_hrs, cph_pneumonia_no_abs_prevl_betas = data_process_hrs_betas(cph_pneumonia_no_abs_prevl_1)
cph_pneumonia_abs_incdt_hrs, cph_pneumonia_abs_incdt_betas = data_process_hrs_betas(cph_pneumonia_abs_incdt_1)
# cph_pneumonia_abs_prevl_hrs, cph_pneumonia_abs_prevl_betas = data_process_hrs_betas(cph_pneumonia_abs_prevl_1)

# %%
cph_urti_no_abs_incdt_hrs, cph_urti_no_abs_incdt_betas = data_process_hrs_betas(cph_urti_no_abs_incdt_1)
cph_urti_no_abs_prevl_hrs, cph_urti_no_abs_prevl_betas = data_process_hrs_betas(cph_urti_no_abs_prevl_1)
cph_urti_abs_incdt_hrs, cph_urti_abs_incdt_betas = data_process_hrs_betas(cph_urti_abs_incdt_1)
cph_urti_abs_prevl_hrs, cph_urti_abs_prevl_betas = data_process_hrs_betas(cph_urti_abs_prevl_1)

# %%
cph_cough_no_abs_incdt_hrs, cph_cough_no_abs_incdt_betas = data_process_hrs_betas(cph_cough_no_abs_incdt_1)
cph_cough_no_abs_prevl_hrs, cph_cough_no_abs_prevl_betas = data_process_hrs_betas(cph_cough_no_abs_prevl_1)
cph_cough_abs_incdt_hrs, cph_cough_abs_incdt_betas = data_process_hrs_betas(cph_cough_abs_incdt_1)
cph_cough_abs_prevl_hrs, cph_cough_abs_prevl_betas = data_process_hrs_betas(cph_cough_abs_prevl_1)

# %%
cph_cough_cold_no_abs_incdt_hrs, cph_cough_cold_no_abs_incdt_betas = data_process_hrs_betas(cph_cough_cold_no_abs_incdt_1)
cph_cough_cold_no_abs_prevl_hrs, cph_cough_cold_no_abs_prevl_betas = data_process_hrs_betas(cph_cough_cold_no_abs_prevl_1)
cph_cough_cold_abs_incdt_hrs, cph_cough_cold_abs_incdt_betas = data_process_hrs_betas(cph_cough_cold_abs_incdt_1)
cph_cough_cold_abs_prevl_hrs, cph_cough_cold_abs_prevl_betas = data_process_hrs_betas(cph_cough_cold_abs_prevl_1)

# %%
cph_throat_no_abs_incdt_hrs, cph_throat_no_abs_incdt_betas = data_process_hrs_betas(cph_throat_no_abs_incdt_1)
cph_throat_no_abs_prevl_hrs, cph_throat_no_abs_prevl_betas = data_process_hrs_betas(cph_throat_no_abs_prevl_1)
cph_throat_abs_incdt_hrs, cph_throat_abs_incdt_betas = data_process_hrs_betas(cph_throat_abs_incdt_1)
cph_throat_abs_prevl_hrs, cph_throat_abs_prevl_betas = data_process_hrs_betas(cph_throat_abs_prevl_1)

# %%
d = {'variable': cph_lrti_no_abs_incdt_hrs['variable'],
     
     'lrti_no_abs_incdt': cph_lrti_no_abs_incdt_hrs['betas'], 
     'lrti_abs_incdt': cph_lrti_abs_incdt_hrs['betas'],
     'lrti_no_abs_prevl': cph_lrti_no_abs_prevl_hrs['betas'], 
     'lrti_abs_prevl': cph_lrti_abs_prevl_hrs['betas'],
     
     'urti_combined_no_abs_incdt': cph_urti_combined_no_abs_incdt_hrs['betas'], 
     'urti_combined_abs_incdt': cph_urti_combined_abs_incdt_hrs['betas'],
     'urti_combined_no_abs_prevl': cph_urti_combined_no_abs_prevl_hrs['betas'], 
     'urti_combined_abs_prevl': cph_urti_combined_abs_prevl_hrs['betas'],
     
     'uti_no_abs_incdt': cph_uti_no_abs_incdt_hrs['betas'], 
     'uti_abs_incdt': cph_uti_abs_incdt_hrs['betas'],
     'uti_no_abs_prevl': cph_uti_no_abs_prevl_hrs['betas'], 
     'uti_abs_prevl': cph_uti_abs_prevl_hrs['betas'],
     
     'sinusitis_no_abs_incdt': cph_sinusitis_no_abs_incdt_hrs['betas'], 
     'sinusitis_abs_incdt': cph_sinusitis_abs_incdt_hrs['betas'],
    #  'sinusitis_no_abs_prevl': cph_sinusitis_no_abs_prevl_hrs['betas'], 
    #  'sinusitis_abs_prevl': cph_sinusitis_abs_prevl_hrs['betas'],
     
     'otmedia_no_abs_incdt': cph_otmedia_no_abs_incdt_hrs['betas'], 
     'otmedia_abs_incdt': cph_otmedia_abs_incdt_hrs['betas'],
     'otmedia_no_abs_prevl': cph_otmedia_no_abs_prevl_hrs['betas'], 
     'otmedia_abs_prevl': cph_otmedia_abs_prevl_hrs['betas'],
     
     'ot_externa_no_abs_incdt': cph_ot_externa_no_abs_incdt_hrs['betas'], 
     'ot_externa_abs_incdt': cph_ot_externa_abs_incdt_hrs['betas'],
     'ot_externa_no_abs_prevl': cph_ot_externa_no_abs_prevl_hrs['betas'], 
    #  'ot_externa_abs_prevl': cph_ot_externa_abs_prevl_hrs['betas'],

     'pneumonia_no_abs_incdt': cph_pneumonia_no_abs_incdt_hrs['betas'], 
     'pneumonia_abs_incdt': cph_pneumonia_abs_incdt_hrs['betas'],
     'pneumonia_no_abs_prevl': cph_pneumonia_no_abs_prevl_hrs['betas'], 
    #  'pneumonia_abs_prevl': cph_pneumonia_abs_prevl_hrs['betas'],

     'urti_no_abs_incdt': cph_urti_no_abs_incdt_hrs['betas'], 
     'urti_abs_incdt': cph_urti_abs_incdt_hrs['betas'],
     'urti_no_abs_prevl': cph_urti_no_abs_prevl_hrs['betas'], 
     'urti_abs_prevl': cph_urti_abs_prevl_hrs['betas'],

     'cough_no_abs_incdt': cph_cough_no_abs_incdt_hrs['betas'], 
     'cough_abs_incdt': cph_cough_abs_incdt_hrs['betas'],
     'cough_no_abs_prevl': cph_cough_no_abs_prevl_hrs['betas'], 
     'cough_abs_prevl': cph_cough_abs_prevl_hrs['betas'],

     'cough_cold_no_abs_incdt': cph_cough_cold_no_abs_incdt_hrs['betas'], 
     'cough_cold_abs_incdt': cph_cough_cold_abs_incdt_hrs['betas'],
     'cough_cold_no_abs_prevl': cph_cough_cold_no_abs_prevl_hrs['betas'], 
     'cough_cold_abs_prevl': cph_cough_cold_abs_prevl_hrs['betas'],

     'throat_no_abs_incdt': cph_throat_no_abs_incdt_hrs['betas'], 
     'throat_abs_incdt': cph_throat_abs_incdt_hrs['betas'],
     'throat_no_abs_prevl': cph_throat_no_abs_prevl_hrs['betas'], 
     'throat_abs_prevl': cph_throat_abs_prevl_hrs['betas'],
    }
data = pd.DataFrame(data=d)

#custom order of variables to fit tables of the manuscript again
data['variable'] = pd.Categorical(data['variable'], ['sex[T.male]', 'age_cat[T.25_34]', 'age_cat[T.35_44]', 'age_cat[T.45_54]', 'age_cat[T.55_64]', 'age_cat[T.65_74]', 'age_cat[T.75_more]', 'bmi_cat[T.underweight]', 'bmi_cat[T.overweight]', 'bmi_cat[T.obese]', 'bmi_cat[T.unknown]', 'ethnicity[T.white]', 'ethnicity[T.unknown]', 'CCI_cat[T.low]', 'CCI_cat[T.medium]', 'CCI_cat[T.high]', 'CCI_cat[T.very_high]', 'smoking_status[T.smoker]', 'smoking_status[T.never_smoked]', 'smoking_status[T.unknown]', 'imd[T.very_affluent]', 'imd[T.medium]', 'imd[T.unaffluent]', 'imd[T.very_unaffluent]', 'imd[T.unknown]', 'season[T.spring]', 'season[T.summer]', 'season[T.winter]', 'region[T.london]', 'region[T.north_east]', 'region[T.north_west]', 'region[T.west_midlands]', 'region[T.yorkshire]', 'region[T.south_east]', 'region[T.east_midlands]', 'region[T.south_west]', 'flu_vaccine[T.yes]', 'antibacterial_brit'])
data = data.sort_values('variable')

#print output in csv
data.to_csv(f'../output/aggregate_hrs_betas/cph_hrs_all_infections.csv', index=False)
data
# Out:
#                           variable lrti_no_abs_incdt      lrti_abs_incdt  \
# 34                     sex[T.male]  0.86 (0.72-1.04)    0.48 (0.26-0.87)
# 4                 age_cat[T.25_34]  0.84 (0.59-1.19)   5.19 (1.15-23.49)
# 5                 age_cat[T.35_44]  1.06 (0.76-1.48)   3.98 (0.84-18.79)
# 6                 age_cat[T.45_54]  0.88 (0.62-1.25)   5.02 (1.11-22.70)
# 7                 age_cat[T.55_64]  0.90 (0.64-1.27)   3.71 (0.78-17.51)
# 8                 age_cat[T.65_74]  1.06 (0.76-1.48)   2.92 (0.59-14.50)
# 9               age_cat[T.75_more]  1.04 (0.74-1.45)    1.43 (0.24-8.54)
# 13          bmi_cat[T.underweight]  1.53 (0.89-2.62)  10.47 (1.16-94.66)
# 12           bmi_cat[T.overweight]  1.19 (0.78-1.80)   3.80 (0.44-32.67)
# 11                bmi_cat[T.obese]  1.09 (0.77-1.55)   3.42 (0.46-25.54)
# 14              bmi_cat[T.unknown]  1.05 (0.72-1.53)   6.61 (0.88-49.71)
# 16              ethnicity[T.white]  0.99 (0.76-1.30)    1.31 (0.54-3.16)
# ...

# %%
d = {'variable': cph_lrti_no_abs_incdt_betas['variable'],
     
     'lrti_no_abs_incdt': cph_lrti_no_abs_incdt_betas['coef'],
     'lrti_no_abs_prevl': cph_lrti_no_abs_prevl_betas['coef'],
     
     'urti_no_abs_incdt': cph_urti_no_abs_incdt_betas['coef'],
     'urti_no_abs_prevl': cph_urti_no_abs_prevl_betas['coef'],
     
     'uti_no_abs_incdt': cph_uti_no_abs_incdt_betas['coef'],
     'uti_no_abs_prevl': cph_uti_no_abs_prevl_betas['coef'],
     
     'sinusitis_no_abs_incdt': cph_sinusitis_no_abs_incdt_betas['coef'],
    #  'sinusitis_no_abs_prevl': cph_sinusitis_no_abs_prevl_betas['coef'],
     
     'otmedia_no_abs_incdt': cph_otmedia_no_abs_incdt_betas['coef'],
     'otmedia_no_abs_prevl': cph_otmedia_no_abs_prevl_betas['coef'],
     
     'ot_externa_no_abs_incdt': cph_ot_externa_no_abs_incdt_betas['coef'],
     'ot_externa_no_abs_prevl': cph_ot_externa_no_abs_prevl_betas['coef'],
    
     'pneumonia_no_abs_incdt': cph_pneumonia_no_abs_incdt_betas['coef'],
    #  'pneumonia_abs_prevl': cph_pneumonia_abs_prevl_betas['coef'], ########replaced

     'cough_no_abs_incdt': cph_cough_no_abs_incdt_betas['coef'],
     'cough_no_abs_prevl': cph_cough_no_abs_prevl_betas['coef'],

     'throat_no_abs_incdt': cph_throat_no_abs_incdt_betas['coef'],
     'throat_no_abs_prevl': cph_throat_no_abs_prevl_betas['coef'],
    }
data = pd.DataFrame(data=d)

#print output in csv
data.to_csv(f'../output/aggregate_hrs_betas/cph_betas_all_infections.csv', index=False)
data
# Out:
#                           variable  lrti_no_abs_incdt  lrti_no_abs_prevl  \
# 0                   CCI_cat[T.low]               0.06               0.06
# 1                CCI_cat[T.medium]               0.01               0.01
# 2                  CCI_cat[T.high]               0.17               0.17
# 3             CCI_cat[T.very_high]              -0.00              -0.00
# 4                 age_cat[T.25_34]              -0.18              -0.18
# 5                 age_cat[T.35_44]               0.06               0.06
# 6                 age_cat[T.45_54]              -0.13              -0.13
# 7                 age_cat[T.55_64]              -0.10              -0.10
# 8                 age_cat[T.65_74]               0.06               0.06
# 9               age_cat[T.75_more]               0.04               0.04
# 10              antibacterial_brit               0.01               0.01
# 11                bmi_cat[T.obese]               0.09               0.09
# ...
