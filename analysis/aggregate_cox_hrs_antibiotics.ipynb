# %% [markdown]
# # Aggregating Hazard Ratios of Prescribed Antibiotics in Cox Models for All Infections

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
warnings.warn('DelftStack')
warnings.warn('Do not show this message')

# %%
cph_lrti_incdt_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_hrs.csv')
cph_lrti_prevl_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_hrs.csv')
cph_lrti_incdt_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_ab_type_hrs.csv')
cph_lrti_prevl_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_ab_type_hrs.csv')
cph_lrti_incdt_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_15_24_hrs.csv')
cph_lrti_incdt_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_25_34_hrs.csv')
cph_lrti_incdt_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_35_44_hrs.csv')
cph_lrti_incdt_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_45_54_hrs.csv')
cph_lrti_incdt_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_55_64_hrs.csv')
cph_lrti_incdt_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_65_74_hrs.csv')
cph_lrti_incdt_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_75_more_hrs.csv')
cph_lrti_prevl_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_15_24_hrs.csv')
cph_lrti_prevl_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_25_34_hrs.csv')
cph_lrti_prevl_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_35_44_hrs.csv')
cph_lrti_prevl_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_45_54_hrs.csv')
cph_lrti_prevl_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_55_64_hrs.csv')
cph_lrti_prevl_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_65_74_hrs.csv')
cph_lrti_prevl_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_75_more_hrs.csv')
cph_lrti_incdt_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_males_hrs.csv')
cph_lrti_incdt_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_females_hrs.csv')
cph_lrti_prevl_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_males_hrs.csv')
cph_lrti_prevl_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_females_hrs.csv')
cph_lrti_incdt_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_prepandemic_hrs.csv')
cph_lrti_incdt_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_during_pandemic_hrs.csv')
cph_lrti_incdt_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_post_2nd_lockdown_hrs.csv')
cph_lrti_prevl_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_prepandemic_hrs.csv')
cph_lrti_prevl_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_during_pandemic_hrs.csv')
cph_lrti_prevl_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_post_2nd_lockdown_hrs.csv')

# %%
cph_urti_combined_incdt_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_hrs.csv')
cph_urti_combined_prevl_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_hrs.csv')
cph_urti_combined_incdt_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_ab_type_hrs.csv')
cph_urti_combined_prevl_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_ab_type_hrs.csv')
cph_urti_combined_incdt_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_15_24_hrs.csv')
cph_urti_combined_incdt_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_25_34_hrs.csv')
cph_urti_combined_incdt_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_35_44_hrs.csv')
cph_urti_combined_incdt_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_45_54_hrs.csv')
cph_urti_combined_incdt_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_55_64_hrs.csv')
cph_urti_combined_incdt_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_65_74_hrs.csv')
cph_urti_combined_incdt_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_75_more_hrs.csv')
cph_urti_combined_prevl_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_15_24_hrs.csv')
cph_urti_combined_prevl_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_25_34_hrs.csv')
cph_urti_combined_prevl_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_35_44_hrs.csv')
cph_urti_combined_prevl_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_45_54_hrs.csv')
cph_urti_combined_prevl_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_55_64_hrs.csv')
cph_urti_combined_prevl_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_65_74_hrs.csv')
cph_urti_combined_prevl_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_75_more_hrs.csv')
cph_urti_combined_incdt_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_males_hrs.csv')
cph_urti_combined_incdt_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_females_hrs.csv')
cph_urti_combined_prevl_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_males_hrs.csv')
cph_urti_combined_prevl_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_females_hrs.csv')
cph_urti_combined_incdt_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_prepandemic_hrs.csv')
cph_urti_combined_incdt_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_during_pandemic_hrs.csv')
cph_urti_combined_incdt_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_post_2nd_lockdown_hrs.csv')
cph_urti_combined_prevl_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_prepandemic_hrs.csv')
cph_urti_combined_prevl_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_during_pandemic_hrs.csv')
cph_urti_combined_prevl_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_post_2nd_lockdown_hrs.csv')

# %%
cph_uti_incdt_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_hrs.csv')
cph_uti_prevl_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_hrs.csv')
cph_uti_incdt_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_ab_type_hrs.csv')
cph_uti_prevl_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_ab_type_hrs.csv')
cph_uti_incdt_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_15_24_hrs.csv')
cph_uti_incdt_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_25_34_hrs.csv')
cph_uti_incdt_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_35_44_hrs.csv')
cph_uti_incdt_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_45_54_hrs.csv')
cph_uti_incdt_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_55_64_hrs.csv')
cph_uti_incdt_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_65_74_hrs.csv')
cph_uti_incdt_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_75_more_hrs.csv')
cph_uti_prevl_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_15_24_hrs.csv')
cph_uti_prevl_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_25_34_hrs.csv')
cph_uti_prevl_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_35_44_hrs.csv')
cph_uti_prevl_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_45_54_hrs.csv')
cph_uti_prevl_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_55_64_hrs.csv')
cph_uti_prevl_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_65_74_hrs.csv')
cph_uti_prevl_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_75_more_hrs.csv')
cph_uti_incdt_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_males_hrs.csv')
cph_uti_incdt_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_females_hrs.csv')
cph_uti_prevl_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_males_hrs.csv')
cph_uti_prevl_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_females_hrs.csv')
cph_uti_incdt_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_prepandemic_hrs.csv')
cph_uti_incdt_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_during_pandemic_hrs.csv')
cph_uti_incdt_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_post_2nd_lockdown_hrs.csv')
cph_uti_prevl_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_prepandemic_hrs.csv')
cph_uti_prevl_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_during_pandemic_hrs.csv')
cph_uti_prevl_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_post_2nd_lockdown_hrs.csv')

# %%
cph_sinusitis_incdt_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_hrs.csv')
cph_sinusitis_prevl_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_hrs.csv')
cph_sinusitis_incdt_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_ab_type_hrs.csv')
cph_sinusitis_prevl_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_ab_type_hrs.csv')
cph_sinusitis_incdt_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_15_24_hrs.csv')
cph_sinusitis_incdt_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_25_34_hrs.csv')
cph_sinusitis_incdt_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_35_44_hrs.csv')
cph_sinusitis_incdt_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_45_54_hrs.csv')
cph_sinusitis_incdt_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_55_64_hrs.csv')
cph_sinusitis_incdt_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_65_74_hrs.csv')
cph_sinusitis_incdt_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_75_more_hrs.csv')
cph_sinusitis_prevl_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_15_24_hrs.csv')
cph_sinusitis_prevl_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_25_34_hrs.csv')
cph_sinusitis_prevl_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_35_44_hrs.csv')
cph_sinusitis_prevl_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_45_54_hrs.csv')
# cph_sinusitis_prevl_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_55_64_hrs.csv')
# cph_sinusitis_prevl_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_65_74_hrs.csv')
cph_sinusitis_prevl_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_75_more_hrs.csv')
cph_sinusitis_incdt_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_males_hrs.csv')
cph_sinusitis_incdt_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_females_hrs.csv')
cph_sinusitis_prevl_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_males_hrs.csv')
cph_sinusitis_prevl_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_females_hrs.csv')
cph_sinusitis_incdt_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_prepandemic_hrs.csv')
cph_sinusitis_incdt_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_during_pandemic_hrs.csv')
cph_sinusitis_incdt_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_post_2nd_lockdown_hrs.csv')
# cph_sinusitis_prevl_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_prepandemic_hrs.csv')
# cph_sinusitis_prevl_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_during_pandemic_hrs.csv')
# cph_sinusitis_prevl_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_post_2nd_lockdown_hrs.csv')

# %%
cph_otmedia_incdt_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_hrs.csv')
cph_otmedia_prevl_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_hrs.csv')
cph_otmedia_incdt_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_ab_type_hrs.csv')
cph_otmedia_prevl_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_ab_type_hrs.csv')
cph_otmedia_incdt_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_15_24_hrs.csv')
cph_otmedia_incdt_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_25_34_hrs.csv')
# cph_otmedia_incdt_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_35_44_hrs.csv')
cph_otmedia_incdt_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_45_54_hrs.csv')
cph_otmedia_incdt_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_55_64_hrs.csv')
cph_otmedia_incdt_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_65_74_hrs.csv')
cph_otmedia_incdt_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_75_more_hrs.csv')
# cph_otmedia_prevl_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_15_24_hrs.csv')
cph_otmedia_prevl_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_25_34_hrs.csv')
# cph_otmedia_prevl_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_35_44_hrs.csv')
cph_otmedia_prevl_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_45_54_hrs.csv')
# cph_otmedia_prevl_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_55_64_hrs.csv')
cph_otmedia_prevl_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_65_74_hrs.csv')
cph_otmedia_prevl_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_75_more_hrs.csv')
cph_otmedia_incdt_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_males_hrs.csv')
cph_otmedia_incdt_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_females_hrs.csv')
# cph_otmedia_prevl_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_males_hrs.csv')
cph_otmedia_prevl_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_females_hrs.csv')
cph_otmedia_incdt_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_prepandemic_hrs.csv')
cph_otmedia_incdt_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_during_pandemic_hrs.csv')
cph_otmedia_incdt_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_post_2nd_lockdown_hrs.csv')
cph_otmedia_prevl_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_prepandemic_hrs.csv')
# cph_otmedia_prevl_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_during_pandemic_hrs.csv')
cph_otmedia_prevl_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_post_2nd_lockdown_hrs.csv')

# %%
cph_ot_externa_incdt_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_hrs.csv')
cph_ot_externa_prevl_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_hrs.csv')
cph_ot_externa_incdt_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_ab_type_hrs.csv')
cph_ot_externa_prevl_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_ab_type_hrs.csv')
cph_ot_externa_incdt_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_15_24_hrs.csv')
cph_ot_externa_incdt_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_25_34_hrs.csv')
cph_ot_externa_incdt_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_35_44_hrs.csv')
cph_ot_externa_incdt_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_45_54_hrs.csv')
cph_ot_externa_incdt_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_55_64_hrs.csv')
cph_ot_externa_incdt_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_65_74_hrs.csv')
cph_ot_externa_incdt_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_75_more_hrs.csv')
cph_ot_externa_prevl_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_15_24_hrs.csv')
cph_ot_externa_prevl_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_25_34_hrs.csv')
cph_ot_externa_prevl_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_35_44_hrs.csv')
cph_ot_externa_prevl_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_45_54_hrs.csv')
cph_ot_externa_prevl_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_55_64_hrs.csv')
# cph_ot_externa_prevl_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_65_74_hrs.csv')
cph_ot_externa_prevl_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_75_more_hrs.csv')
cph_ot_externa_incdt_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_males_hrs.csv')
cph_ot_externa_incdt_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_females_hrs.csv')
cph_ot_externa_prevl_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_males_hrs.csv')
cph_ot_externa_prevl_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_females_hrs.csv')
cph_ot_externa_incdt_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_prepandemic_hrs.csv')
cph_ot_externa_incdt_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_during_pandemic_hrs.csv')
cph_ot_externa_incdt_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_post_2nd_lockdown_hrs.csv')
cph_ot_externa_prevl_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_prepandemic_hrs.csv')
cph_ot_externa_prevl_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_during_pandemic_hrs.csv')
cph_ot_externa_prevl_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_post_2nd_lockdown_hrs.csv')

# %%
cph_pneumonia_incdt_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_hrs.csv')
cph_pneumonia_prevl_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_hrs.csv')
cph_pneumonia_incdt_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_ab_type_hrs.csv')
cph_pneumonia_prevl_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_ab_type_hrs.csv')
cph_pneumonia_incdt_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_15_24_hrs.csv')
cph_pneumonia_incdt_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_25_34_hrs.csv')
cph_pneumonia_incdt_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_35_44_hrs.csv')
cph_pneumonia_incdt_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_45_54_hrs.csv')
cph_pneumonia_incdt_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_55_64_hrs.csv')
cph_pneumonia_incdt_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_65_74_hrs.csv')
cph_pneumonia_incdt_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_75_more_hrs.csv')
# cph_pneumonia_prevl_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_15_24_hrs.csv')
# cph_pneumonia_prevl_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_25_34_hrs.csv')
# cph_pneumonia_prevl_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_35_44_hrs.csv')
cph_pneumonia_prevl_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_45_54_hrs.csv')
cph_pneumonia_prevl_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_55_64_hrs.csv')
cph_pneumonia_prevl_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_65_74_hrs.csv')
cph_pneumonia_prevl_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_75_more_hrs.csv')
cph_pneumonia_incdt_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_males_hrs.csv')
cph_pneumonia_incdt_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_females_hrs.csv')
cph_pneumonia_prevl_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_males_hrs.csv')
cph_pneumonia_prevl_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_females_hrs.csv')
cph_pneumonia_incdt_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_prepandemic_hrs.csv')
cph_pneumonia_incdt_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_during_pandemic_hrs.csv')
cph_pneumonia_incdt_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_post_2nd_lockdown_hrs.csv')
cph_pneumonia_prevl_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_prepandemic_hrs.csv')
cph_pneumonia_prevl_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_during_pandemic_hrs.csv')
cph_pneumonia_prevl_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_post_2nd_lockdown_hrs.csv')

# %%
cph_urti_incdt_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_hrs.csv')
cph_urti_prevl_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_hrs.csv')
cph_urti_incdt_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_ab_type_hrs.csv')
cph_urti_prevl_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_ab_type_hrs.csv')
cph_urti_incdt_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_15_24_hrs.csv')
cph_urti_incdt_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_25_34_hrs.csv')
cph_urti_incdt_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_35_44_hrs.csv')
cph_urti_incdt_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_45_54_hrs.csv')
cph_urti_incdt_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_55_64_hrs.csv')
cph_urti_incdt_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_65_74_hrs.csv')
cph_urti_incdt_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_75_more_hrs.csv')
# cph_urti_prevl_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_15_24_hrs.csv')
cph_urti_prevl_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_25_34_hrs.csv')
cph_urti_prevl_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_35_44_hrs.csv')
cph_urti_prevl_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_45_54_hrs.csv')
cph_urti_prevl_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_55_64_hrs.csv')
cph_urti_prevl_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_65_74_hrs.csv')
cph_urti_prevl_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_75_more_hrs.csv')
cph_urti_incdt_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_males_hrs.csv')
cph_urti_incdt_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_females_hrs.csv')
cph_urti_prevl_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_males_hrs.csv')
cph_urti_prevl_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_females_hrs.csv')
cph_urti_incdt_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_prepandemic_hrs.csv')
cph_urti_incdt_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_during_pandemic_hrs.csv')
cph_urti_incdt_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_post_2nd_lockdown_hrs.csv')
cph_urti_prevl_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_prepandemic_hrs.csv')
cph_urti_prevl_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_during_pandemic_hrs.csv')
cph_urti_prevl_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_post_2nd_lockdown_hrs.csv')

# %%
cph_cough_incdt_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_hrs.csv')
cph_cough_prevl_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_hrs.csv')
cph_cough_incdt_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_ab_type_hrs.csv')
cph_cough_prevl_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_ab_type_hrs.csv')
cph_cough_incdt_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_15_24_hrs.csv')
cph_cough_incdt_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_25_34_hrs.csv')
cph_cough_incdt_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_35_44_hrs.csv')
cph_cough_incdt_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_45_54_hrs.csv')
cph_cough_incdt_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_55_64_hrs.csv')
cph_cough_incdt_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_65_74_hrs.csv')
cph_cough_incdt_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_75_more_hrs.csv')
cph_cough_prevl_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_15_24_hrs.csv')
cph_cough_prevl_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_25_34_hrs.csv')
cph_cough_prevl_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_35_44_hrs.csv')
cph_cough_prevl_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_45_54_hrs.csv')
# cph_cough_prevl_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_55_64_hrs.csv')
cph_cough_prevl_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_65_74_hrs.csv')
cph_cough_prevl_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_75_more_hrs.csv')
cph_cough_incdt_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_males_hrs.csv')
cph_cough_incdt_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_females_hrs.csv')
cph_cough_prevl_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_males_hrs.csv')
cph_cough_prevl_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_females_hrs.csv')
cph_cough_incdt_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_prepandemic_hrs.csv')
cph_cough_incdt_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_during_pandemic_hrs.csv')
cph_cough_incdt_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_post_2nd_lockdown_hrs.csv')
cph_cough_prevl_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_prepandemic_hrs.csv')
cph_cough_prevl_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_during_pandemic_hrs.csv')
cph_cough_prevl_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_post_2nd_lockdown_hrs.csv')

# %%
cph_cough_cold_incdt_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_hrs.csv')
cph_cough_cold_prevl_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_hrs.csv')
cph_cough_cold_incdt_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_ab_type_hrs.csv')
cph_cough_cold_prevl_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_ab_type_hrs.csv')
cph_cough_cold_incdt_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_15_24_hrs.csv')
cph_cough_cold_incdt_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_25_34_hrs.csv')
cph_cough_cold_incdt_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_35_44_hrs.csv')
cph_cough_cold_incdt_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_45_54_hrs.csv')
cph_cough_cold_incdt_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_55_64_hrs.csv')
cph_cough_cold_incdt_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_65_74_hrs.csv')
cph_cough_cold_incdt_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_75_more_hrs.csv')
cph_cough_cold_prevl_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_15_24_hrs.csv')
cph_cough_cold_prevl_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_25_34_hrs.csv')
cph_cough_cold_prevl_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_35_44_hrs.csv')
cph_cough_cold_prevl_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_45_54_hrs.csv')
cph_cough_cold_prevl_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_55_64_hrs.csv')
cph_cough_cold_prevl_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_65_74_hrs.csv')
cph_cough_cold_prevl_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_75_more_hrs.csv')
cph_cough_cold_incdt_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_males_hrs.csv')
cph_cough_cold_incdt_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_females_hrs.csv')
cph_cough_cold_prevl_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_males_hrs.csv')
cph_cough_cold_prevl_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_females_hrs.csv')
cph_cough_cold_incdt_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_prepandemic_hrs.csv')
cph_cough_cold_incdt_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_during_pandemic_hrs.csv')
cph_cough_cold_incdt_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_post_2nd_lockdown_hrs.csv')
cph_cough_cold_prevl_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_prepandemic_hrs.csv')
cph_cough_cold_prevl_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_during_pandemic_hrs.csv')
cph_cough_cold_prevl_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_post_2nd_lockdown_hrs.csv')

# %%
cph_throat_incdt_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_hrs.csv')
cph_throat_prevl_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_hrs.csv')
cph_throat_incdt_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_ab_type_hrs.csv')
cph_throat_prevl_ab_type_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_ab_type_hrs.csv')
cph_throat_incdt_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_15_24_hrs.csv')
cph_throat_incdt_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_25_34_hrs.csv')
cph_throat_incdt_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_35_44_hrs.csv')
cph_throat_incdt_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_45_54_hrs.csv')
cph_throat_incdt_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_55_64_hrs.csv')
cph_throat_incdt_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_65_74_hrs.csv')
cph_throat_incdt_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_75_more_hrs.csv')
cph_throat_prevl_15_24_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_15_24_hrs.csv')
cph_throat_prevl_25_34_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_25_34_hrs.csv')
cph_throat_prevl_35_44_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_35_44_hrs.csv')
cph_throat_prevl_45_54_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_45_54_hrs.csv')
cph_throat_prevl_55_64_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_55_64_hrs.csv')
cph_throat_prevl_65_74_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_65_74_hrs.csv')
cph_throat_prevl_75_more_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_75_more_hrs.csv')
cph_throat_incdt_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_males_hrs.csv')
cph_throat_incdt_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_females_hrs.csv')
cph_throat_prevl_males_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_males_hrs.csv')
cph_throat_prevl_females_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_females_hrs.csv')
cph_throat_incdt_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_prepandemic_hrs.csv')
cph_throat_incdt_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_during_pandemic_hrs.csv')
cph_throat_incdt_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_post_2nd_lockdown_hrs.csv')
cph_throat_prevl_prepandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_prepandemic_hrs.csv')
cph_throat_prevl_during_pandemic_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_during_pandemic_hrs.csv')
cph_throat_prevl_post_2nd_lockdown_hrs = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_post_2nd_lockdown_hrs.csv')

# %%
# cph_lrti_incdt = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_summary.html')
# cph_lrti_incdt_1 = cph_lrti_incdt[1]
# cph_lrti_prevl = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_summary.html')
# cph_lrti_prevl_1 = cph_lrti_incdt[1]
# cph_lrti_incdt_ab_type = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_ab_type_summary.html')
# cph_lrti_incdt_ab_type_1 = cph_lrti_incdt_ab_type[1]
# cph_lrti_prevl_ab_type = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_ab_type_summary.html')
# cph_lrti_prevl_ab_type_1 = cph_lrti_incdt_ab_type[1]
# cph_lrti_incdt_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_15_24_summary.html')
# cph_lrti_incdt_ab_15_24_1 = cph_lrti_incdt_ab_15_24[1]
# cph_lrti_prevl_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_15_24_summary.html')
# cph_lrti_prevl_ab_15_24_1 = cph_lrti_incdt_ab_15_24[1]
# cph_lrti_incdt_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_25_34_summary.html')
# cph_lrti_incdt_ab_25_34_1 = cph_lrti_incdt_ab_25_34[1]
# cph_lrti_prevl_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_25_34_summary.html')
# cph_lrti_prevl_ab_25_34_1 = cph_lrti_incdt_ab_25_34[1]
# cph_lrti_incdt_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_35_44_summary.html')
# cph_lrti_incdt_ab_35_44_1 = cph_lrti_incdt_ab_35_44[1]
# cph_lrti_prevl_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_35_44_summary.html')
# cph_lrti_prevl_ab_35_44_1 = cph_lrti_incdt_ab_35_44[1]
# cph_lrti_incdt_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_45_54_summary.html')
# cph_lrti_incdt_ab_45_54_1 = cph_lrti_incdt_ab_45_54[1]
# cph_lrti_prevl_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_45_54_summary.html')
# cph_lrti_prevl_ab_45_54_1 = cph_lrti_incdt_ab_45_54[1]
# cph_lrti_incdt_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_55_64_summary.html')
# cph_lrti_incdt_ab_55_64_1 = cph_lrti_incdt_ab_55_64[1]
# cph_lrti_prevl_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_55_64_summary.html')
# cph_lrti_prevl_ab_55_64_1 = cph_lrti_incdt_ab_55_64[1]
# cph_lrti_incdt_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_65_74_summary.html')
# cph_lrti_incdt_ab_65_74_1 = cph_lrti_incdt_ab_65_74[1]
# cph_lrti_prevl_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_65_74_summary.html')
# cph_lrti_prevl_ab_65_74_1 = cph_lrti_incdt_ab_65_74[1]
# cph_lrti_incdt_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_75_more_summary.html')
# cph_lrti_incdt_ab_75_more_1 = cph_lrti_incdt_ab_75_more[1]
# cph_lrti_prevl_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_75_more_summary.html')
# cph_lrti_prevl_ab_75_more_1 = cph_lrti_incdt_ab_75_more[1]
# cph_lrti_incdt_ab_male = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_males_summary.html')
# cph_lrti_incdt_ab_male_1 = cph_lrti_incdt_ab_male[1]
# cph_lrti_incdt_ab_female = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_females_summary.html')
# cph_lrti_incdt_ab_female_1 = cph_lrti_incdt_ab_female[1]
# cph_lrti_prevl_ab_male = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_males_summary.html')
# cph_lrti_prevl_ab_male_1 = cph_lrti_prevl_ab_male[1]
# cph_lrti_prevl_ab_female = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_females_summary.html')
# cph_lrti_prevl_ab_female_1 = cph_lrti_prevl_ab_female[1]
# cph_lrti_incdt_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_prepandemic_summary.html') #cph_lrti_incdt_prepandemic_summary
# cph_lrti_incdt_ab_prepandemic_1 = cph_lrti_incdt_ab_prepandemic[1]
# cph_lrti_prevl_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_prepandemic_summary.html')
# cph_lrti_prevl_ab_prepandemic_1 = cph_lrti_prevl_ab_prepandemic[1]
# cph_lrti_incdt_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_during_pandemic_summary.html')
# cph_lrti_incdt_ab_during_pandemic_1 = cph_lrti_incdt_ab_during_pandemic[1]
# cph_lrti_prevl_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_during_pandemic_summary.html')
# cph_lrti_prevl_ab_during_pandemic_1 = cph_lrti_prevl_ab_during_pandemic[1]
# cph_lrti_incdt_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_incdt_post_2nd_lockdown_summary.html')
# cph_lrti_incdt_ab_post_2nd_lockdown_1 = cph_lrti_incdt_ab_post_2nd_lockdown[1]
# cph_lrti_prevl_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_prevl_post_2nd_lockdown_summary.html')
# cph_lrti_prevl_ab_post_2nd_lockdown_1 = cph_lrti_prevl_ab_post_2nd_lockdown[1]

# %%
# cph_urti_combined_incdt = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_summary.html')
# cph_urti_combined_incdt_1 = cph_urti_combined_incdt[1]
# cph_urti_combined_prevl = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_summary.html')
# cph_urti_combined_prevl_1 = cph_urti_combined_incdt[1]
# cph_urti_combined_incdt_ab_type = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_ab_type_summary.html')
# cph_urti_combined_incdt_ab_type_1 = cph_urti_combined_incdt_ab_type[1]
# cph_urti_combined_prevl_ab_type = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_ab_type_summary.html')
# cph_urti_combined_prevl_ab_type_1 = cph_urti_combined_incdt_ab_type[1]
# cph_urti_combined_incdt_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_15_24_summary.html')
# cph_urti_combined_incdt_ab_15_24_1 = cph_urti_combined_incdt_ab_15_24[1]
# cph_urti_combined_prevl_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_15_24_summary.html')
# cph_urti_combined_prevl_ab_15_24_1 = cph_urti_combined_incdt_ab_15_24[1]
# cph_urti_combined_incdt_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_25_34_summary.html')
# cph_urti_combined_incdt_ab_25_34_1 = cph_urti_combined_incdt_ab_25_34[1]
# cph_urti_combined_prevl_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_25_34_summary.html')
# cph_urti_combined_prevl_ab_25_34_1 = cph_urti_combined_incdt_ab_25_34[1]
# cph_urti_combined_incdt_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_35_44_summary.html')
# cph_urti_combined_incdt_ab_35_44_1 = cph_urti_combined_incdt_ab_35_44[1]
# cph_urti_combined_prevl_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_35_44_summary.html')
# cph_urti_combined_prevl_ab_35_44_1 = cph_urti_combined_incdt_ab_35_44[1]
# cph_urti_combined_incdt_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_45_54_summary.html')
# cph_urti_combined_incdt_ab_45_54_1 = cph_urti_combined_incdt_ab_45_54[1]
# cph_urti_combined_prevl_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_45_54_summary.html')
# cph_urti_combined_prevl_ab_45_54_1 = cph_urti_combined_incdt_ab_45_54[1]
# cph_urti_combined_incdt_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_55_64_summary.html')
# cph_urti_combined_incdt_ab_55_64_1 = cph_urti_combined_incdt_ab_55_64[1]
# cph_urti_combined_prevl_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_55_64_summary.html')
# cph_urti_combined_prevl_ab_55_64_1 = cph_urti_combined_incdt_ab_55_64[1]
# cph_urti_combined_incdt_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_65_74_summary.html')
# cph_urti_combined_incdt_ab_65_74_1 = cph_urti_combined_incdt_ab_65_74[1]
# cph_urti_combined_prevl_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_65_74_summary.html')
# cph_urti_combined_prevl_ab_65_74_1 = cph_urti_combined_incdt_ab_65_74[1]
# cph_urti_combined_incdt_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_75_more_summary.html')
# cph_urti_combined_incdt_ab_75_more_1 = cph_urti_combined_incdt_ab_75_more[1]
# cph_urti_combined_prevl_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_75_more_summary.html')
# cph_urti_combined_prevl_ab_75_more_1 = cph_urti_combined_incdt_ab_75_more[1]
# cph_urti_combined_incdt_ab_male = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_males_summary.html')
# cph_urti_combined_incdt_ab_male_1 = cph_urti_combined_incdt_ab_male[1]
# cph_urti_combined_incdt_ab_female = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_females_summary.html')
# cph_urti_combined_incdt_ab_female_1 = cph_urti_combined_incdt_ab_female[1]
# cph_urti_combined_prevl_ab_male = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_males_summary.html')
# cph_urti_combined_prevl_ab_male_1 = cph_urti_combined_prevl_ab_male[1]
# cph_urti_combined_prevl_ab_female = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_females_summary.html')
# cph_urti_combined_prevl_ab_female_1 = cph_urti_combined_prevl_ab_female[1]
# cph_urti_combined_incdt_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_prepandemic_summary.html') 
# cph_urti_combined_incdt_ab_prepandemic_1 = cph_urti_combined_incdt_ab_prepandemic[1]
# cph_urti_combined_prevl_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_prepandemic_summary.html')
# cph_urti_combined_prevl_ab_prepandemic_1 = cph_urti_combined_prevl_ab_prepandemic[1]
# cph_urti_combined_incdt_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_during_pandemic_summary.html')
# cph_urti_combined_incdt_ab_during_pandemic_1 = cph_urti_combined_incdt_ab_during_pandemic[1]
# cph_urti_combined_prevl_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_during_pandemic_summary.html')
# cph_urti_combined_prevl_ab_during_pandemic_1 = cph_urti_combined_prevl_ab_during_pandemic[1]
# cph_urti_combined_incdt_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_incdt_post_2nd_lockdown_summary.html')
# cph_urti_combined_incdt_ab_post_2nd_lockdown_1 = cph_urti_combined_incdt_ab_post_2nd_lockdown[1]
# cph_urti_combined_prevl_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_prevl_post_2nd_lockdown_summary.html')
# cph_urti_combined_prevl_ab_post_2nd_lockdown_1 = cph_urti_combined_prevl_ab_post_2nd_lockdown[1]

# %%
# cph_uti_incdt = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_summary.html')
# cph_uti_incdt_1 = cph_uti_incdt[1]
# cph_uti_prevl = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_summary.html')
# cph_uti_prevl_1 = cph_uti_incdt[1]
# cph_uti_incdt_ab_type = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_ab_type_summary.html')
# cph_uti_incdt_ab_type_1 = cph_uti_incdt_ab_type[1]
# cph_uti_prevl_ab_type = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_ab_type_summary.html')
# cph_uti_prevl_ab_type_1 = cph_uti_incdt_ab_type[1]
# cph_uti_incdt_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_15_24_summary.html')
# cph_uti_incdt_ab_15_24_1 = cph_uti_incdt_ab_15_24[1]
# cph_uti_prevl_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_15_24_summary.html')
# cph_uti_prevl_ab_15_24_1 = cph_uti_incdt_ab_15_24[1]
# cph_uti_incdt_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_25_34_summary.html')
# cph_uti_incdt_ab_25_34_1 = cph_uti_incdt_ab_25_34[1]
# cph_uti_prevl_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_25_34_summary.html')
# cph_uti_prevl_ab_25_34_1 = cph_uti_incdt_ab_25_34[1]
# cph_uti_incdt_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_35_44_summary.html')
# cph_uti_incdt_ab_35_44_1 = cph_uti_incdt_ab_35_44[1]
# cph_uti_prevl_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_35_44_summary.html')
# cph_uti_prevl_ab_35_44_1 = cph_uti_incdt_ab_35_44[1]
# cph_uti_incdt_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_45_54_summary.html')
# cph_uti_incdt_ab_45_54_1 = cph_uti_incdt_ab_45_54[1]
# cph_uti_prevl_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_45_54_summary.html')
# cph_uti_prevl_ab_45_54_1 = cph_uti_incdt_ab_45_54[1]
# cph_uti_incdt_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_55_64_summary.html')
# cph_uti_incdt_ab_55_64_1 = cph_uti_incdt_ab_55_64[1]
# cph_uti_prevl_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_55_64_summary.html')
# cph_uti_prevl_ab_55_64_1 = cph_uti_incdt_ab_55_64[1]
# cph_uti_incdt_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_65_74_summary.html')
# cph_uti_incdt_ab_65_74_1 = cph_uti_incdt_ab_65_74[1]
# cph_uti_prevl_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_65_74_summary.html')
# cph_uti_prevl_ab_65_74_1 = cph_uti_incdt_ab_65_74[1]
# cph_uti_incdt_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_75_more_summary.html')
# cph_uti_incdt_ab_75_more_1 = cph_uti_incdt_ab_75_more[1]
# cph_uti_prevl_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_75_more_summary.html')
# cph_uti_prevl_ab_75_more_1 = cph_uti_incdt_ab_75_more[1]
# cph_uti_incdt_ab_male = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_males_summary.html')
# cph_uti_incdt_ab_male_1 = cph_uti_incdt_ab_male[1]
# cph_uti_incdt_ab_female = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_females_summary.html')
# cph_uti_incdt_ab_female_1 = cph_uti_incdt_ab_female[1]
# cph_uti_prevl_ab_male = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_males_summary.html')
# cph_uti_prevl_ab_male_1 = cph_uti_prevl_ab_male[1]
# cph_uti_prevl_ab_female = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_females_summary.html')
# cph_uti_prevl_ab_female_1 = cph_uti_prevl_ab_female[1]
# cph_uti_incdt_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_prepandemic_summary.html') 
# cph_uti_incdt_ab_prepandemic_1 = cph_uti_incdt_ab_prepandemic[1]
# cph_uti_prevl_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_prepandemic_summary.html')
# cph_uti_prevl_ab_prepandemic_1 = cph_uti_prevl_ab_prepandemic[1]
# cph_uti_incdt_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_during_pandemic_summary.html')
# cph_uti_incdt_ab_during_pandemic_1 = cph_uti_incdt_ab_during_pandemic[1]
# cph_uti_prevl_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_during_pandemic_summary.html')
# cph_uti_prevl_ab_during_pandemic_1 = cph_uti_prevl_ab_during_pandemic[1]
# cph_uti_incdt_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_incdt_post_2nd_lockdown_summary.html')
# cph_uti_incdt_ab_post_2nd_lockdown_1 = cph_uti_incdt_ab_post_2nd_lockdown[1]
# cph_uti_prevl_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_prevl_post_2nd_lockdown_summary.html')
# cph_uti_prevl_ab_post_2nd_lockdown_1 = cph_uti_prevl_ab_post_2nd_lockdown[1]

# %%
# cph_sinusitis_incdt = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_summary.html')
# cph_sinusitis_incdt_1 = cph_sinusitis_incdt[1]
# cph_sinusitis_prevl = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_summary.html')
# cph_sinusitis_prevl_1 = cph_sinusitis_incdt[1]
# cph_sinusitis_incdt_ab_type = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_ab_type_summary.html')
# cph_sinusitis_incdt_ab_type_1 = cph_sinusitis_incdt_ab_type[1]
# cph_sinusitis_prevl_ab_type = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_ab_type_summary.html')
# cph_sinusitis_prevl_ab_type_1 = cph_sinusitis_incdt_ab_type[1]
# cph_sinusitis_incdt_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_15_24_summary.html')
# cph_sinusitis_incdt_ab_15_24_1 = cph_sinusitis_incdt_ab_15_24[1]
# cph_sinusitis_prevl_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_15_24_summary.html')
# cph_sinusitis_prevl_ab_15_24_1 = cph_sinusitis_incdt_ab_15_24[1]
# cph_sinusitis_incdt_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_25_34_summary.html')
# cph_sinusitis_incdt_ab_25_34_1 = cph_sinusitis_incdt_ab_25_34[1]
# cph_sinusitis_prevl_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_25_34_summary.html')
# cph_sinusitis_prevl_ab_25_34_1 = cph_sinusitis_incdt_ab_25_34[1]
# cph_sinusitis_incdt_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_35_44_summary.html')
# cph_sinusitis_incdt_ab_35_44_1 = cph_sinusitis_incdt_ab_35_44[1]
# cph_sinusitis_prevl_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_35_44_summary.html')
# cph_sinusitis_prevl_ab_35_44_1 = cph_sinusitis_incdt_ab_35_44[1]
# cph_sinusitis_incdt_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_45_54_summary.html')
# cph_sinusitis_incdt_ab_45_54_1 = cph_sinusitis_incdt_ab_45_54[1]
# cph_sinusitis_prevl_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_45_54_summary.html')
# cph_sinusitis_prevl_ab_45_54_1 = cph_sinusitis_incdt_ab_45_54[1]
# cph_sinusitis_incdt_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_55_64_summary.html')
# cph_sinusitis_incdt_ab_55_64_1 = cph_sinusitis_incdt_ab_55_64[1]
# # cph_sinusitis_prevl_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_55_64_summary.html')
# # cph_sinusitis_prevl_ab_55_64_1 = cph_sinusitis_incdt_ab_55_64[1]
# cph_sinusitis_incdt_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_65_74_summary.html')
# cph_sinusitis_incdt_ab_65_74_1 = cph_sinusitis_incdt_ab_65_74[1]
# # cph_sinusitis_prevl_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_65_74_summary.html')
# # cph_sinusitis_prevl_ab_65_74_1 = cph_sinusitis_incdt_ab_65_74[1]
# cph_sinusitis_incdt_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_75_more_summary.html')
# cph_sinusitis_incdt_ab_75_more_1 = cph_sinusitis_incdt_ab_75_more[1]
# cph_sinusitis_prevl_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_75_more_summary.html')
# cph_sinusitis_prevl_ab_75_more_1 = cph_sinusitis_incdt_ab_75_more[1]
# cph_sinusitis_incdt_ab_male = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_males_summary.html')
# cph_sinusitis_incdt_ab_male_1 = cph_sinusitis_incdt_ab_male[1]
# cph_sinusitis_incdt_ab_female = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_females_summary.html')
# cph_sinusitis_incdt_ab_female_1 = cph_sinusitis_incdt_ab_female[1]
# cph_sinusitis_prevl_ab_male = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_males_summary.html')
# cph_sinusitis_prevl_ab_male_1 = cph_sinusitis_prevl_ab_male[1]
# cph_sinusitis_prevl_ab_female = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_females_summary.html')
# cph_sinusitis_prevl_ab_female_1 = cph_sinusitis_prevl_ab_female[1]
# cph_sinusitis_incdt_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_prepandemic_summary.html') 
# cph_sinusitis_incdt_ab_prepandemic_1 = cph_sinusitis_incdt_ab_prepandemic[1]
# # cph_sinusitis_prevl_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_prepandemic_summary.html')
# # cph_sinusitis_prevl_ab_prepandemic_1 = cph_sinusitis_prevl_ab_prepandemic[1]
# cph_sinusitis_incdt_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_during_pandemic_summary.html')
# cph_sinusitis_incdt_ab_during_pandemic_1 = cph_sinusitis_incdt_ab_during_pandemic[1]
# # cph_sinusitis_prevl_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_during_pandemic_summary.html')
# # cph_sinusitis_prevl_ab_during_pandemic_1 = cph_sinusitis_prevl_ab_during_pandemic[1]
# cph_sinusitis_incdt_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_incdt_post_2nd_lockdown_summary.html')
# cph_sinusitis_incdt_ab_post_2nd_lockdown_1 = cph_sinusitis_incdt_ab_post_2nd_lockdown[1]
# # cph_sinusitis_prevl_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_prevl_post_2nd_lockdown_summary.html')
# # cph_sinusitis_prevl_ab_post_2nd_lockdown_1 = cph_sinusitis_prevl_ab_post_2nd_lockdown[1]

# %%
# cph_otmedia_incdt = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_summary.html')
# cph_otmedia_incdt_1 = cph_otmedia_incdt[1]
# cph_otmedia_prevl = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_summary.html')
# cph_otmedia_prevl_1 = cph_otmedia_incdt[1]
# cph_otmedia_incdt_ab_type = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_ab_type_summary.html')
# cph_otmedia_incdt_ab_type_1 = cph_otmedia_incdt_ab_type[1]
# cph_otmedia_prevl_ab_type = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_ab_type_summary.html')
# cph_otmedia_prevl_ab_type_1 = cph_otmedia_incdt_ab_type[1]
# cph_otmedia_incdt_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_15_24_summary.html')
# cph_otmedia_incdt_ab_15_24_1 = cph_otmedia_incdt_ab_15_24[1]
# # cph_otmedia_prevl_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_15_24_summary.html')
# # cph_otmedia_prevl_ab_15_24_1 = cph_otmedia_incdt_ab_15_24[1]
# cph_otmedia_incdt_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_25_34_summary.html')
# cph_otmedia_incdt_ab_25_34_1 = cph_otmedia_incdt_ab_25_34[1]
# cph_otmedia_prevl_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_25_34_summary.html')
# cph_otmedia_prevl_ab_25_34_1 = cph_otmedia_incdt_ab_25_34[1]
# # cph_otmedia_incdt_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_35_44_summary.html')
# # cph_otmedia_incdt_ab_35_44_1 = cph_otmedia_incdt_ab_35_44[1]
# # cph_otmedia_prevl_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_35_44_summary.html')
# # cph_otmedia_prevl_ab_35_44_1 = cph_otmedia_incdt_ab_35_44[1]
# cph_otmedia_incdt_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_45_54_summary.html')
# cph_otmedia_incdt_ab_45_54_1 = cph_otmedia_incdt_ab_45_54[1]
# cph_otmedia_prevl_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_45_54_summary.html')
# cph_otmedia_prevl_ab_45_54_1 = cph_otmedia_incdt_ab_45_54[1]
# cph_otmedia_incdt_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_55_64_summary.html')
# cph_otmedia_incdt_ab_55_64_1 = cph_otmedia_incdt_ab_55_64[1]
# # cph_otmedia_prevl_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_55_64_summary.html')
# # cph_otmedia_prevl_ab_55_64_1 = cph_otmedia_incdt_ab_55_64[1]
# cph_otmedia_incdt_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_65_74_summary.html')
# cph_otmedia_incdt_ab_65_74_1 = cph_otmedia_incdt_ab_65_74[1]
# # cph_otmedia_prevl_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_65_74_summary.html')
# # cph_otmedia_prevl_ab_65_74_1 = cph_otmedia_incdt_ab_65_74[1]
# cph_otmedia_incdt_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_75_more_summary.html')
# cph_otmedia_incdt_ab_75_more_1 = cph_otmedia_incdt_ab_75_more[1]
# cph_otmedia_prevl_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_75_more_summary.html')
# cph_otmedia_prevl_ab_75_more_1 = cph_otmedia_incdt_ab_75_more[1]
# cph_otmedia_incdt_ab_male = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_males_summary.html')
# cph_otmedia_incdt_ab_male_1 = cph_otmedia_incdt_ab_male[1]
# cph_otmedia_incdt_ab_female = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_females_summary.html')
# cph_otmedia_incdt_ab_female_1 = cph_otmedia_incdt_ab_female[1]
# cph_otmedia_prevl_ab_male = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_males_summary.html')
# cph_otmedia_prevl_ab_male_1 = cph_otmedia_prevl_ab_male[1]
# cph_otmedia_prevl_ab_female = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_females_summary.html')
# cph_otmedia_prevl_ab_female_1 = cph_otmedia_prevl_ab_female[1]
# cph_otmedia_incdt_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_prepandemic_summary.html') 
# cph_otmedia_incdt_ab_prepandemic_1 = cph_otmedia_incdt_ab_prepandemic[1]
# cph_otmedia_prevl_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_prepandemic_summary.html')
# cph_otmedia_prevl_ab_prepandemic_1 = cph_otmedia_prevl_ab_prepandemic[1]
# cph_otmedia_incdt_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_during_pandemic_summary.html')
# cph_otmedia_incdt_ab_during_pandemic_1 = cph_otmedia_incdt_ab_during_pandemic[1]
# # cph_otmedia_prevl_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_during_pandemic_summary.html')
# # cph_otmedia_prevl_ab_during_pandemic_1 = cph_otmedia_prevl_ab_during_pandemic[1]
# cph_otmedia_incdt_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_incdt_post_2nd_lockdown_summary.html')
# cph_otmedia_incdt_ab_post_2nd_lockdown_1 = cph_otmedia_incdt_ab_post_2nd_lockdown[1]
# cph_otmedia_prevl_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_prevl_post_2nd_lockdown_summary.html')
# cph_otmedia_prevl_ab_post_2nd_lockdown_1 = cph_otmedia_prevl_ab_post_2nd_lockdown[1]

# %%
# cph_ot_externa_incdt = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_summary.html')
# cph_ot_externa_incdt_1 = cph_ot_externa_incdt[1]
# cph_ot_externa_prevl = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_summary.html')
# cph_ot_externa_prevl_1 = cph_ot_externa_incdt[1]
# cph_ot_externa_incdt_ab_type = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_ab_type_summary.html')
# cph_ot_externa_incdt_ab_type_1 = cph_ot_externa_incdt_ab_type[1]
# cph_ot_externa_prevl_ab_type = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_ab_type_summary.html')
# cph_ot_externa_prevl_ab_type_1 = cph_ot_externa_incdt_ab_type[1]
# cph_ot_externa_incdt_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_15_24_summary.html')
# cph_ot_externa_incdt_ab_15_24_1 = cph_ot_externa_incdt_ab_15_24[1]
# cph_ot_externa_prevl_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_15_24_summary.html')
# cph_ot_externa_prevl_ab_15_24_1 = cph_ot_externa_incdt_ab_15_24[1]
# cph_ot_externa_incdt_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_25_34_summary.html')
# cph_ot_externa_incdt_ab_25_34_1 = cph_ot_externa_incdt_ab_25_34[1]
# cph_ot_externa_prevl_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_25_34_summary.html')
# cph_ot_externa_prevl_ab_25_34_1 = cph_ot_externa_incdt_ab_25_34[1]
# cph_ot_externa_incdt_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_35_44_summary.html')
# cph_ot_externa_incdt_ab_35_44_1 = cph_ot_externa_incdt_ab_35_44[1]
# cph_ot_externa_prevl_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_35_44_summary.html')
# cph_ot_externa_prevl_ab_35_44_1 = cph_ot_externa_incdt_ab_35_44[1]
# cph_ot_externa_incdt_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_45_54_summary.html')
# cph_ot_externa_incdt_ab_45_54_1 = cph_ot_externa_incdt_ab_45_54[1]
# cph_ot_externa_prevl_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_45_54_summary.html')
# cph_ot_externa_prevl_ab_45_54_1 = cph_ot_externa_incdt_ab_45_54[1]
# cph_ot_externa_incdt_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_55_64_summary.html')
# cph_ot_externa_incdt_ab_55_64_1 = cph_ot_externa_incdt_ab_55_64[1]
# cph_ot_externa_prevl_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_55_64_summary.html')
# cph_ot_externa_prevl_ab_55_64_1 = cph_ot_externa_incdt_ab_55_64[1]
# cph_ot_externa_incdt_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_65_74_summary.html')
# cph_ot_externa_incdt_ab_65_74_1 = cph_ot_externa_incdt_ab_65_74[1]
# # cph_ot_externa_prevl_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_65_74_summary.html')
# # cph_ot_externa_prevl_ab_65_74_1 = cph_ot_externa_incdt_ab_65_74[1]
# cph_ot_externa_incdt_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_75_more_summary.html')
# cph_ot_externa_incdt_ab_75_more_1 = cph_ot_externa_incdt_ab_75_more[1]
# cph_ot_externa_prevl_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_75_more_summary.html')
# cph_ot_externa_prevl_ab_75_more_1 = cph_ot_externa_incdt_ab_75_more[1]
# cph_ot_externa_incdt_ab_male = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_males_summary.html')
# cph_ot_externa_incdt_ab_male_1 = cph_ot_externa_incdt_ab_male[1]
# cph_ot_externa_incdt_ab_female = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_females_summary.html')
# cph_ot_externa_incdt_ab_female_1 = cph_ot_externa_incdt_ab_female[1]
# cph_ot_externa_prevl_ab_male = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_males_summary.html')
# cph_ot_externa_prevl_ab_male_1 = cph_ot_externa_prevl_ab_male[1]
# cph_ot_externa_prevl_ab_female = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_females_summary.html')
# cph_ot_externa_prevl_ab_female_1 = cph_ot_externa_prevl_ab_female[1]
# cph_ot_externa_incdt_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_prepandemic_summary.html') 
# cph_ot_externa_incdt_ab_prepandemic_1 = cph_ot_externa_incdt_ab_prepandemic[1]
# cph_ot_externa_prevl_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_prepandemic_summary.html')
# cph_ot_externa_prevl_ab_prepandemic_1 = cph_ot_externa_prevl_ab_prepandemic[1]
# cph_ot_externa_incdt_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_during_pandemic_summary.html')
# cph_ot_externa_incdt_ab_during_pandemic_1 = cph_ot_externa_incdt_ab_during_pandemic[1]
# cph_ot_externa_prevl_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_during_pandemic_summary.html')
# cph_ot_externa_prevl_ab_during_pandemic_1 = cph_ot_externa_prevl_ab_during_pandemic[1]
# cph_ot_externa_incdt_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_incdt_post_2nd_lockdown_summary.html')
# cph_ot_externa_incdt_ab_post_2nd_lockdown_1 = cph_ot_externa_incdt_ab_post_2nd_lockdown[1]
# cph_ot_externa_prevl_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_prevl_post_2nd_lockdown_summary.html')
# cph_ot_externa_prevl_ab_post_2nd_lockdown_1 = cph_ot_externa_prevl_ab_post_2nd_lockdown[1]

# %%
# cph_pneumonia_incdt = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_summary.html')
# cph_pneumonia_incdt_1 = cph_pneumonia_incdt[1]
# cph_pneumonia_prevl = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_summary.html')
# cph_pneumonia_prevl_1 = cph_pneumonia_incdt[1]
# cph_pneumonia_incdt_ab_type = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_ab_type_summary.html')
# cph_pneumonia_incdt_ab_type_1 = cph_pneumonia_incdt_ab_type[1]
# cph_pneumonia_prevl_ab_type = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_ab_type_summary.html')
# cph_pneumonia_prevl_ab_type_1 = cph_pneumonia_incdt_ab_type[1]
# cph_pneumonia_incdt_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_15_24_summary.html')
# cph_pneumonia_incdt_ab_15_24_1 = cph_pneumonia_incdt_ab_15_24[1]
# # cph_pneumonia_prevl_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_15_24_summary.html')
# # cph_pneumonia_prevl_ab_15_24_1 = cph_pneumonia_incdt_ab_15_24[1]
# cph_pneumonia_incdt_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_25_34_summary.html')
# cph_pneumonia_incdt_ab_25_34_1 = cph_pneumonia_incdt_ab_25_34[1]
# # cph_pneumonia_prevl_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_25_34_summary.html')
# # cph_pneumonia_prevl_ab_25_34_1 = cph_pneumonia_incdt_ab_25_34[1]
# cph_pneumonia_incdt_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_35_44_summary.html')
# cph_pneumonia_incdt_ab_35_44_1 = cph_pneumonia_incdt_ab_35_44[1]
# # cph_pneumonia_prevl_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_35_44_summary.html')
# # cph_pneumonia_prevl_ab_35_44_1 = cph_pneumonia_incdt_ab_35_44[1]
# cph_pneumonia_incdt_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_45_54_summary.html')
# cph_pneumonia_incdt_ab_45_54_1 = cph_pneumonia_incdt_ab_45_54[1]
# cph_pneumonia_prevl_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_45_54_summary.html')
# cph_pneumonia_prevl_ab_45_54_1 = cph_pneumonia_incdt_ab_45_54[1]
# cph_pneumonia_incdt_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_55_64_summary.html')
# cph_pneumonia_incdt_ab_55_64_1 = cph_pneumonia_incdt_ab_55_64[1]
# cph_pneumonia_prevl_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_55_64_summary.html')
# cph_pneumonia_prevl_ab_55_64_1 = cph_pneumonia_incdt_ab_55_64[1]
# cph_pneumonia_incdt_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_65_74_summary.html')
# cph_pneumonia_incdt_ab_65_74_1 = cph_pneumonia_incdt_ab_65_74[1]
# # cph_pneumonia_prevl_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_65_74_summary.html')
# # cph_pneumonia_prevl_ab_65_74_1 = cph_pneumonia_incdt_ab_65_74[1]
# cph_pneumonia_incdt_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_75_more_summary.html')
# cph_pneumonia_incdt_ab_75_more_1 = cph_pneumonia_incdt_ab_75_more[1]
# cph_pneumonia_prevl_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_75_more_summary.html')
# cph_pneumonia_prevl_ab_75_more_1 = cph_pneumonia_incdt_ab_75_more[1]
# cph_pneumonia_incdt_ab_male = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_males_summary.html')
# cph_pneumonia_incdt_ab_male_1 = cph_pneumonia_incdt_ab_male[1]
# cph_pneumonia_incdt_ab_female = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_females_summary.html')
# cph_pneumonia_incdt_ab_female_1 = cph_pneumonia_incdt_ab_female[1]
# cph_pneumonia_prevl_ab_male = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_males_summary.html')
# cph_pneumonia_prevl_ab_male_1 = cph_pneumonia_prevl_ab_male[1]
# cph_pneumonia_prevl_ab_female = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_females_summary.html')
# cph_pneumonia_prevl_ab_female_1 = cph_pneumonia_prevl_ab_female[1]
# cph_pneumonia_incdt_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_prepandemic_summary.html') 
# cph_pneumonia_incdt_ab_prepandemic_1 = cph_pneumonia_incdt_ab_prepandemic[1]
# cph_pneumonia_prevl_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_prepandemic_summary.html')
# cph_pneumonia_prevl_ab_prepandemic_1 = cph_pneumonia_prevl_ab_prepandemic[1]
# cph_pneumonia_incdt_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_during_pandemic_summary.html')
# cph_pneumonia_incdt_ab_during_pandemic_1 = cph_pneumonia_incdt_ab_during_pandemic[1]
# # cph_pneumonia_prevl_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_during_pandemic_summary.html')
# # cph_pneumonia_prevl_ab_during_pandemic_1 = cph_pneumonia_prevl_ab_during_pandemic[1]
# cph_pneumonia_incdt_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_incdt_post_2nd_lockdown_summary.html')
# cph_pneumonia_incdt_ab_post_2nd_lockdown_1 = cph_pneumonia_incdt_ab_post_2nd_lockdown[1]
# cph_pneumonia_prevl_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_prevl_post_2nd_lockdown_summary.html')
# cph_pneumonia_prevl_ab_post_2nd_lockdown_1 = cph_pneumonia_prevl_ab_post_2nd_lockdown[1]

# %%
# cph_urti_incdt = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_summary.html')
# cph_urti_incdt_1 = cph_urti_incdt[1]
# cph_urti_prevl = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_summary.html')
# cph_urti_prevl_1 = cph_urti_incdt[1]
# cph_urti_incdt_ab_type = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_ab_type_summary.html')
# cph_urti_incdt_ab_type_1 = cph_urti_incdt_ab_type[1]
# cph_urti_prevl_ab_type = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_ab_type_summary.html')
# cph_urti_prevl_ab_type_1 = cph_urti_incdt_ab_type[1]
# cph_urti_incdt_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_15_24_summary.html')
# cph_urti_incdt_ab_15_24_1 = cph_urti_incdt_ab_15_24[1]
# # cph_urti_prevl_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_15_24_summary.html')
# # cph_urti_prevl_ab_15_24_1 = cph_urti_incdt_ab_15_24[1]
# cph_urti_incdt_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_25_34_summary.html')
# cph_urti_incdt_ab_25_34_1 = cph_urti_incdt_ab_25_34[1]
# cph_urti_prevl_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_25_34_summary.html')
# cph_urti_prevl_ab_25_34_1 = cph_urti_incdt_ab_25_34[1]
# cph_urti_incdt_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_35_44_summary.html')
# cph_urti_incdt_ab_35_44_1 = cph_urti_incdt_ab_35_44[1]
# # cph_urti_prevl_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_35_44_summary.html')
# # cph_urti_prevl_ab_35_44_1 = cph_urti_incdt_ab_35_44[1]
# cph_urti_incdt_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_45_54_summary.html')
# cph_urti_incdt_ab_45_54_1 = cph_urti_incdt_ab_45_54[1]
# cph_urti_prevl_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_45_54_summary.html')
# cph_urti_prevl_ab_45_54_1 = cph_urti_incdt_ab_45_54[1]
# cph_urti_incdt_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_55_64_summary.html')
# cph_urti_incdt_ab_55_64_1 = cph_urti_incdt_ab_55_64[1]
# cph_urti_prevl_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_55_64_summary.html')
# cph_urti_prevl_ab_55_64_1 = cph_urti_incdt_ab_55_64[1]
# cph_urti_incdt_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_65_74_summary.html')
# cph_urti_incdt_ab_65_74_1 = cph_urti_incdt_ab_65_74[1]
# cph_urti_prevl_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_65_74_summary.html')
# cph_urti_prevl_ab_65_74_1 = cph_urti_incdt_ab_65_74[1]
# cph_urti_incdt_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_75_more_summary.html')
# cph_urti_incdt_ab_75_more_1 = cph_urti_incdt_ab_75_more[1]
# cph_urti_prevl_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_75_more_summary.html')
# cph_urti_prevl_ab_75_more_1 = cph_urti_incdt_ab_75_more[1]
# cph_urti_incdt_ab_male = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_males_summary.html')
# cph_urti_incdt_ab_male_1 = cph_urti_incdt_ab_male[1]
# cph_urti_incdt_ab_female = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_females_summary.html')
# cph_urti_incdt_ab_female_1 = cph_urti_incdt_ab_female[1]
# cph_urti_prevl_ab_male = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_males_summary.html')
# cph_urti_prevl_ab_male_1 = cph_urti_prevl_ab_male[1]
# cph_urti_prevl_ab_female = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_females_summary.html')
# cph_urti_prevl_ab_female_1 = cph_urti_prevl_ab_female[1]
# cph_urti_incdt_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_prepandemic_summary.html') 
# cph_urti_incdt_ab_prepandemic_1 = cph_urti_incdt_ab_prepandemic[1]
# cph_urti_prevl_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_prepandemic_summary.html')
# cph_urti_prevl_ab_prepandemic_1 = cph_urti_prevl_ab_prepandemic[1]
# cph_urti_incdt_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_during_pandemic_summary.html')
# cph_urti_incdt_ab_during_pandemic_1 = cph_urti_incdt_ab_during_pandemic[1]
# cph_urti_prevl_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_during_pandemic_summary.html')
# cph_urti_prevl_ab_during_pandemic_1 = cph_urti_prevl_ab_during_pandemic[1]
# cph_urti_incdt_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_incdt_post_2nd_lockdown_summary.html')
# cph_urti_incdt_ab_post_2nd_lockdown_1 = cph_urti_incdt_ab_post_2nd_lockdown[1]
# cph_urti_prevl_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_prevl_post_2nd_lockdown_summary.html')
# cph_urti_prevl_ab_post_2nd_lockdown_1 = cph_urti_prevl_ab_post_2nd_lockdown[1]

# %%
# cph_cough_incdt = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_summary.html')
# cph_cough_incdt_1 = cph_cough_incdt[1]
# cph_cough_prevl = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_summary.html')
# cph_cough_prevl_1 = cph_cough_incdt[1]
# cph_cough_incdt_ab_type = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_ab_type_summary.html')
# cph_cough_incdt_ab_type_1 = cph_cough_incdt_ab_type[1]
# cph_cough_prevl_ab_type = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_ab_type_summary.html')
# cph_cough_prevl_ab_type_1 = cph_cough_incdt_ab_type[1]
# cph_cough_incdt_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_15_24_summary.html')
# cph_cough_incdt_ab_15_24_1 = cph_cough_incdt_ab_15_24[1]
# cph_cough_prevl_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_15_24_summary.html')
# cph_cough_prevl_ab_15_24_1 = cph_cough_incdt_ab_15_24[1]
# cph_cough_incdt_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_25_34_summary.html')
# cph_cough_incdt_ab_25_34_1 = cph_cough_incdt_ab_25_34[1]
# cph_cough_prevl_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_25_34_summary.html')
# cph_cough_prevl_ab_25_34_1 = cph_cough_incdt_ab_25_34[1]
# cph_cough_incdt_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_35_44_summary.html')
# cph_cough_incdt_ab_35_44_1 = cph_cough_incdt_ab_35_44[1]
# cph_cough_prevl_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_35_44_summary.html')
# cph_cough_prevl_ab_35_44_1 = cph_cough_incdt_ab_35_44[1]
# cph_cough_incdt_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_45_54_summary.html')
# cph_cough_incdt_ab_45_54_1 = cph_cough_incdt_ab_45_54[1]
# cph_cough_prevl_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_45_54_summary.html')
# cph_cough_prevl_ab_45_54_1 = cph_cough_incdt_ab_45_54[1]
# cph_cough_incdt_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_55_64_summary.html')
# cph_cough_incdt_ab_55_64_1 = cph_cough_incdt_ab_55_64[1]
# # cph_cough_prevl_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_55_64_summary.html')
# # cph_cough_prevl_ab_55_64_1 = cph_cough_incdt_ab_55_64[1]
# cph_cough_incdt_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_65_74_summary.html')
# cph_cough_incdt_ab_65_74_1 = cph_cough_incdt_ab_65_74[1]
# cph_cough_prevl_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_65_74_summary.html')
# cph_cough_prevl_ab_65_74_1 = cph_cough_incdt_ab_65_74[1]
# cph_cough_incdt_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_75_more_summary.html')
# cph_cough_incdt_ab_75_more_1 = cph_cough_incdt_ab_75_more[1]
# cph_cough_prevl_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_75_more_summary.html')
# cph_cough_prevl_ab_75_more_1 = cph_cough_incdt_ab_75_more[1]
# cph_cough_incdt_ab_male = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_males_summary.html')
# cph_cough_incdt_ab_male_1 = cph_cough_incdt_ab_male[1]
# cph_cough_incdt_ab_female = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_females_summary.html')
# cph_cough_incdt_ab_female_1 = cph_cough_incdt_ab_female[1]
# cph_cough_prevl_ab_male = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_males_summary.html')
# cph_cough_prevl_ab_male_1 = cph_cough_prevl_ab_male[1]
# cph_cough_prevl_ab_female = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_females_summary.html')
# cph_cough_prevl_ab_female_1 = cph_cough_prevl_ab_female[1]
# cph_cough_incdt_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_prepandemic_summary.html') 
# cph_cough_incdt_ab_prepandemic_1 = cph_cough_incdt_ab_prepandemic[1]
# cph_cough_prevl_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_prepandemic_summary.html')
# cph_cough_prevl_ab_prepandemic_1 = cph_cough_prevl_ab_prepandemic[1]
# cph_cough_incdt_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_during_pandemic_summary.html')
# cph_cough_incdt_ab_during_pandemic_1 = cph_cough_incdt_ab_during_pandemic[1]
# cph_cough_prevl_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_during_pandemic_summary.html')
# cph_cough_prevl_ab_during_pandemic_1 = cph_cough_prevl_ab_during_pandemic[1]
# cph_cough_incdt_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_incdt_post_2nd_lockdown_summary.html')
# cph_cough_incdt_ab_post_2nd_lockdown_1 = cph_cough_incdt_ab_post_2nd_lockdown[1]
# cph_cough_prevl_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_prevl_post_2nd_lockdown_summary.html')
# cph_cough_prevl_ab_post_2nd_lockdown_1 = cph_cough_prevl_ab_post_2nd_lockdown[1]

# %%
# cph_cough_cold_incdt = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_summary.html')
# cph_cough_cold_incdt_1 = cph_cough_cold_incdt[1]
# cph_cough_cold_prevl = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_summary.html')
# cph_cough_cold_prevl_1 = cph_cough_cold_incdt[1]
# cph_cough_cold_incdt_ab_type = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_ab_type_summary.html')
# cph_cough_cold_incdt_ab_type_1 = cph_cough_cold_incdt_ab_type[1]
# cph_cough_cold_prevl_ab_type = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_ab_type_summary.html')
# cph_cough_cold_prevl_ab_type_1 = cph_cough_cold_incdt_ab_type[1]
# cph_cough_cold_incdt_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_15_24_summary.html')
# cph_cough_cold_incdt_ab_15_24_1 = cph_cough_cold_incdt_ab_15_24[1]
# cph_cough_cold_prevl_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_15_24_summary.html')
# cph_cough_cold_prevl_ab_15_24_1 = cph_cough_cold_incdt_ab_15_24[1]
# cph_cough_cold_incdt_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_25_34_summary.html')
# cph_cough_cold_incdt_ab_25_34_1 = cph_cough_cold_incdt_ab_25_34[1]
# cph_cough_cold_prevl_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_25_34_summary.html')
# cph_cough_cold_prevl_ab_25_34_1 = cph_cough_cold_incdt_ab_25_34[1]
# cph_cough_cold_incdt_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_35_44_summary.html')
# cph_cough_cold_incdt_ab_35_44_1 = cph_cough_cold_incdt_ab_35_44[1]
# cph_cough_cold_prevl_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_35_44_summary.html')
# cph_cough_cold_prevl_ab_35_44_1 = cph_cough_cold_incdt_ab_35_44[1]
# cph_cough_cold_incdt_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_45_54_summary.html')
# cph_cough_cold_incdt_ab_45_54_1 = cph_cough_cold_incdt_ab_45_54[1]
# cph_cough_cold_prevl_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_45_54_summary.html')
# cph_cough_cold_prevl_ab_45_54_1 = cph_cough_cold_incdt_ab_45_54[1]
# cph_cough_cold_incdt_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_55_64_summary.html')
# cph_cough_cold_incdt_ab_55_64_1 = cph_cough_cold_incdt_ab_55_64[1]
# cph_cough_cold_prevl_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_55_64_summary.html')
# cph_cough_cold_prevl_ab_55_64_1 = cph_cough_cold_incdt_ab_55_64[1]
# cph_cough_cold_incdt_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_65_74_summary.html')
# cph_cough_cold_incdt_ab_65_74_1 = cph_cough_cold_incdt_ab_65_74[1]
# cph_cough_cold_prevl_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_65_74_summary.html')
# cph_cough_cold_prevl_ab_65_74_1 = cph_cough_cold_incdt_ab_65_74[1]
# cph_cough_cold_incdt_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_75_more_summary.html')
# cph_cough_cold_incdt_ab_75_more_1 = cph_cough_cold_incdt_ab_75_more[1]
# cph_cough_cold_prevl_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_75_more_summary.html')
# cph_cough_cold_prevl_ab_75_more_1 = cph_cough_cold_incdt_ab_75_more[1]
# cph_cough_cold_incdt_ab_male = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_males_summary.html')
# cph_cough_cold_incdt_ab_male_1 = cph_cough_cold_incdt_ab_male[1]
# cph_cough_cold_incdt_ab_female = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_females_summary.html')
# cph_cough_cold_incdt_ab_female_1 = cph_cough_cold_incdt_ab_female[1]
# cph_cough_cold_prevl_ab_male = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_males_summary.html')
# cph_cough_cold_prevl_ab_male_1 = cph_cough_cold_prevl_ab_male[1]
# cph_cough_cold_prevl_ab_female = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_females_summary.html')
# cph_cough_cold_prevl_ab_female_1 = cph_cough_cold_prevl_ab_female[1]
# cph_cough_cold_incdt_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_prepandemic_summary.html') 
# cph_cough_cold_incdt_ab_prepandemic_1 = cph_cough_cold_incdt_ab_prepandemic[1]
# cph_cough_cold_prevl_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_prepandemic_summary.html')
# cph_cough_cold_prevl_ab_prepandemic_1 = cph_cough_cold_prevl_ab_prepandemic[1]
# cph_cough_cold_incdt_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_during_pandemic_summary.html')
# cph_cough_cold_incdt_ab_during_pandemic_1 = cph_cough_cold_incdt_ab_during_pandemic[1]
# cph_cough_cold_prevl_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_during_pandemic_summary.html')
# cph_cough_cold_prevl_ab_during_pandemic_1 = cph_cough_cold_prevl_ab_during_pandemic[1]
# cph_cough_cold_incdt_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_incdt_post_2nd_lockdown_summary.html')
# cph_cough_cold_incdt_ab_post_2nd_lockdown_1 = cph_cough_cold_incdt_ab_post_2nd_lockdown[1]
# cph_cough_cold_prevl_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_prevl_post_2nd_lockdown_summary.html')
# cph_cough_cold_prevl_ab_post_2nd_lockdown_1 = cph_cough_cold_prevl_ab_post_2nd_lockdown[1]

# %%
# cph_throat_incdt = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_summary.html')
# cph_throat_incdt_1 = cph_throat_incdt[1]
# cph_throat_prevl = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_summary.html')
# cph_throat_prevl_1 = cph_throat_incdt[1]
# cph_throat_incdt_ab_type = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_ab_type_summary.html')
# cph_throat_incdt_ab_type_1 = cph_throat_incdt_ab_type[1]
# cph_throat_prevl_ab_type = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_ab_type_summary.html')
# cph_throat_prevl_ab_type_1 = cph_throat_incdt_ab_type[1]
# cph_throat_incdt_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_15_24_summary.html')
# cph_throat_incdt_ab_15_24_1 = cph_throat_incdt_ab_15_24[1]
# cph_throat_prevl_ab_15_24 = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_15_24_summary.html')
# cph_throat_prevl_ab_15_24_1 = cph_throat_incdt_ab_15_24[1]
# cph_throat_incdt_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_25_34_summary.html')
# cph_throat_incdt_ab_25_34_1 = cph_throat_incdt_ab_25_34[1]
# cph_throat_prevl_ab_25_34 = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_25_34_summary.html')
# cph_throat_prevl_ab_25_34_1 = cph_throat_incdt_ab_25_34[1]
# cph_throat_incdt_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_35_44_summary.html')
# cph_throat_incdt_ab_35_44_1 = cph_throat_incdt_ab_35_44[1]
# cph_throat_prevl_ab_35_44 = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_35_44_summary.html')
# cph_throat_prevl_ab_35_44_1 = cph_throat_incdt_ab_35_44[1]
# cph_throat_incdt_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_45_54_summary.html')
# cph_throat_incdt_ab_45_54_1 = cph_throat_incdt_ab_45_54[1]
# cph_throat_prevl_ab_45_54 = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_45_54_summary.html')
# cph_throat_prevl_ab_45_54_1 = cph_throat_incdt_ab_45_54[1]
# cph_throat_incdt_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_55_64_summary.html')
# cph_throat_incdt_ab_55_64_1 = cph_throat_incdt_ab_55_64[1]
# cph_throat_prevl_ab_55_64 = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_55_64_summary.html')
# cph_throat_prevl_ab_55_64_1 = cph_throat_incdt_ab_55_64[1]
# cph_throat_incdt_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_65_74_summary.html')
# cph_throat_incdt_ab_65_74_1 = cph_throat_incdt_ab_65_74[1]
# cph_throat_prevl_ab_65_74 = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_65_74_summary.html')
# cph_throat_prevl_ab_65_74_1 = cph_throat_incdt_ab_65_74[1]
# cph_throat_incdt_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_75_more_summary.html')
# cph_throat_incdt_ab_75_more_1 = cph_throat_incdt_ab_75_more[1]
# cph_throat_prevl_ab_75_more = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_75_more_summary.html')
# cph_throat_prevl_ab_75_more_1 = cph_throat_incdt_ab_75_more[1]
# cph_throat_incdt_ab_male = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_males_summary.html')
# cph_throat_incdt_ab_male_1 = cph_throat_incdt_ab_male[1]
# cph_throat_incdt_ab_female = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_females_summary.html')
# cph_throat_incdt_ab_female_1 = cph_throat_incdt_ab_female[1]
# cph_throat_prevl_ab_male = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_males_summary.html')
# cph_throat_prevl_ab_male_1 = cph_throat_prevl_ab_male[1]
# cph_throat_prevl_ab_female = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_females_summary.html')
# cph_throat_prevl_ab_female_1 = cph_throat_prevl_ab_female[1]
# cph_throat_incdt_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_prepandemic_summary.html') 
# cph_throat_incdt_ab_prepandemic_1 = cph_throat_incdt_ab_prepandemic[1]
# cph_throat_prevl_ab_prepandemic = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_prepandemic_summary.html')
# cph_throat_prevl_ab_prepandemic_1 = cph_throat_prevl_ab_prepandemic[1]
# cph_throat_incdt_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_during_pandemic_summary.html')
# cph_throat_incdt_ab_during_pandemic_1 = cph_throat_incdt_ab_during_pandemic[1]
# cph_throat_prevl_ab_during_pandemic = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_during_pandemic_summary.html')
# cph_throat_prevl_ab_during_pandemic_1 = cph_throat_prevl_ab_during_pandemic[1]
# cph_throat_incdt_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_incdt_post_2nd_lockdown_summary.html')
# cph_throat_incdt_ab_post_2nd_lockdown_1 = cph_throat_incdt_ab_post_2nd_lockdown[1]
# cph_throat_prevl_ab_post_2nd_lockdown = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_prevl_post_2nd_lockdown_summary.html')
# cph_throat_prevl_ab_post_2nd_lockdown_1 = cph_throat_prevl_ab_post_2nd_lockdown[1]

# %%
def data_process_hrs_betas(data_ab_crude, data_ab_type, data_ab_15_24_strat, data_ab_25_34_strat, data_ab_35_44_strat, data_ab_45_54_strat, data_ab_55_64_strat, data_ab_65_74_strat, data_ab_75_more_strat, data_ab_male_strat, data_ab_female_strat, data_ab_prepandemic_strat, data_ab_during_pandemic_strat, data_ab_post_2nd_lockdown_strat):#, ):# cph_lrti_incdt_ab_prepandemic_1):#, , data_ab_female_strat):
    data_ab_crude.columns = ['variable', 'exp(coef)', '95% lower-bound', '95% upper-bound']
    data_ab_type.columns = ['variable', 'exp(coef)', '95% lower-bound', '95% upper-bound']
    data_ab_15_24_strat.columns = ['variable', 'exp(coef)', '95% lower-bound', '95% upper-bound']
    data_ab_25_34_strat.columns = ['variable', 'exp(coef)', '95% lower-bound', '95% upper-bound']
    data_ab_35_44_strat.columns = ['variable', 'exp(coef)', '95% lower-bound', '95% upper-bound']
    data_ab_45_54_strat.columns = ['variable', 'exp(coef)', '95% lower-bound', '95% upper-bound']
    data_ab_55_64_strat.columns = ['variable', 'exp(coef)', '95% lower-bound', '95% upper-bound']
    data_ab_65_74_strat.columns = ['variable', 'exp(coef)', '95% lower-bound', '95% upper-bound']
    data_ab_75_more_strat.columns = ['variable', 'exp(coef)', '95% lower-bound', '95% upper-bound']
    data_ab_male_strat.columns = ['variable', 'exp(coef)', '95% lower-bound', '95% upper-bound']
    data_ab_female_strat.columns = ['variable', 'exp(coef)', '95% lower-bound', '95% upper-bound']
    data_ab_prepandemic_strat.columns = ['variable', 'exp(coef)', '95% lower-bound', '95% upper-bound']
    data_ab_during_pandemic_strat.columns = ['variable', 'exp(coef)', '95% lower-bound', '95% upper-bound']
    data_ab_post_2nd_lockdown_strat.columns = ['variable', 'exp(coef)', '95% lower-bound', '95% upper-bound']

    data_ab_crude = data_ab_crude[data_ab_crude['variable'].str.contains('ab_')]
    data_ab_type = data_ab_type[data_ab_type['variable'].str.contains('ab_')]
    data_ab_15_24_strat = data_ab_15_24_strat[data_ab_15_24_strat['variable'].str.contains('ab_')]
    data_ab_25_34_strat = data_ab_25_34_strat[data_ab_25_34_strat['variable'].str.contains('ab_')]
    data_ab_35_44_strat = data_ab_35_44_strat[data_ab_35_44_strat['variable'].str.contains('ab_')]
    data_ab_45_54_strat = data_ab_45_54_strat[data_ab_45_54_strat['variable'].str.contains('ab_')]
    data_ab_55_64_strat = data_ab_55_64_strat[data_ab_55_64_strat['variable'].str.contains('ab_')]
    data_ab_65_74_strat = data_ab_65_74_strat[data_ab_65_74_strat['variable'].str.contains('ab_')]
    data_ab_75_more_strat = data_ab_75_more_strat[data_ab_75_more_strat['variable'].str.contains('ab_')]
    data_ab_male_strat = data_ab_male_strat[data_ab_male_strat['variable'].str.contains('ab_')]
    data_ab_female_strat = data_ab_female_strat[data_ab_female_strat['variable'].str.contains('ab_')]
    data_ab_prepandemic_strat = data_ab_prepandemic_strat[data_ab_prepandemic_strat['variable'].str.contains('ab_')]
    data_ab_during_pandemic_strat = data_ab_during_pandemic_strat[data_ab_during_pandemic_strat['variable'].str.contains('ab_')]
    data_ab_post_2nd_lockdown_strat = data_ab_post_2nd_lockdown_strat[data_ab_post_2nd_lockdown_strat['variable'].str.contains('ab_')]

    data_ab_15_24_strat['variable'] = data_ab_15_24_strat['variable'].astype(str) + '_15_24'
    data_ab_25_34_strat['variable'] = data_ab_25_34_strat['variable'].astype(str) + '_25_34'
    data_ab_35_44_strat['variable'] = data_ab_35_44_strat['variable'].astype(str) + '_35_44'
    data_ab_45_54_strat['variable'] = data_ab_45_54_strat['variable'].astype(str) + '_45_54'
    data_ab_55_64_strat['variable'] = data_ab_55_64_strat['variable'].astype(str) + '_55_64'
    data_ab_65_74_strat['variable'] = data_ab_65_74_strat['variable'].astype(str) + '_65_74'
    data_ab_75_more_strat['variable'] = data_ab_75_more_strat['variable'].astype(str) + '_75_more'
    data_ab_male_strat['variable'] = data_ab_male_strat['variable'].astype(str) + '_male'
    data_ab_female_strat['variable'] = data_ab_female_strat['variable'].astype(str) + '_female'
    data_ab_prepandemic_strat['variable'] = data_ab_prepandemic_strat['variable'].astype(str) + '_prepandemic'
    data_ab_during_pandemic_strat['variable'] = data_ab_during_pandemic_strat['variable'].astype(str) + '_during_pandemic'
    data_ab_post_2nd_lockdown_strat['variable'] = data_ab_post_2nd_lockdown_strat['variable'].astype(str) + '_post_2nd_lockdown'    

    data_hrs_abs = pd.concat([data_ab_crude, data_ab_type, data_ab_15_24_strat, data_ab_25_34_strat, data_ab_35_44_strat, data_ab_45_54_strat, data_ab_55_64_strat, data_ab_65_74_strat, data_ab_75_more_strat, data_ab_male_strat, data_ab_female_strat, data_ab_prepandemic_strat, data_ab_during_pandemic_strat, data_ab_post_2nd_lockdown_strat], axis = 0) #, , , data_ab_during_pandemic_strat, data_ab_female_strat

    data_hrs_abs['exp(coef)'] = data_hrs_abs['exp(coef)'].apply(lambda x: "{:.2f}".format(x))
    data_hrs_abs['95% lower-bound'] = data_hrs_abs['95% lower-bound'].apply(lambda x: "{:.2f}".format(x))
    data_hrs_abs['95% upper-bound'] = data_hrs_abs['95% upper-bound'].apply(lambda x: "{:.2f}".format(x))
    data_hrs_abs['betas'] = data_hrs_abs['exp(coef)'].astype(str) + " (" + data_hrs_abs['95% lower-bound'].astype(str) + '-' + data_hrs_abs['95% upper-bound'].astype(str) + ')'
    data_hrs_abs = data_hrs_abs[['variable', 'betas']]
    data_hrs_abs = data_hrs_abs.reset_index(drop=True)

    return data_hrs_abs

# %%
cph_lrti_incdt_hrs = data_process_hrs_betas(cph_lrti_incdt_hrs, cph_lrti_incdt_ab_type_hrs, cph_lrti_incdt_15_24_hrs, cph_lrti_incdt_25_34_hrs, cph_lrti_incdt_35_44_hrs, cph_lrti_incdt_45_54_hrs, cph_lrti_incdt_55_64_hrs, cph_lrti_incdt_65_74_hrs, cph_lrti_incdt_75_more_hrs, cph_lrti_incdt_males_hrs, cph_lrti_incdt_females_hrs, cph_lrti_incdt_prepandemic_hrs, cph_lrti_incdt_during_pandemic_hrs, cph_lrti_incdt_post_2nd_lockdown_hrs)
cph_lrti_prevl_hrs = data_process_hrs_betas(cph_lrti_prevl_hrs, cph_lrti_prevl_ab_type_hrs, cph_lrti_prevl_15_24_hrs, cph_lrti_prevl_25_34_hrs, cph_lrti_prevl_35_44_hrs, cph_lrti_prevl_45_54_hrs, cph_lrti_prevl_55_64_hrs, cph_lrti_prevl_65_74_hrs, cph_lrti_prevl_75_more_hrs, cph_lrti_prevl_males_hrs, cph_lrti_prevl_females_hrs, cph_lrti_prevl_prepandemic_hrs, cph_lrti_prevl_during_pandemic_hrs, cph_lrti_prevl_post_2nd_lockdown_hrs)

cph_urti_combined_incdt_hrs = data_process_hrs_betas(cph_urti_combined_incdt_hrs, cph_urti_combined_incdt_ab_type_hrs, cph_urti_combined_incdt_15_24_hrs, cph_urti_combined_incdt_25_34_hrs, cph_urti_combined_incdt_35_44_hrs, cph_urti_combined_incdt_45_54_hrs, cph_urti_combined_incdt_55_64_hrs, cph_urti_combined_incdt_65_74_hrs, cph_urti_combined_incdt_75_more_hrs, cph_urti_combined_incdt_males_hrs, cph_urti_combined_incdt_females_hrs, cph_urti_combined_incdt_prepandemic_hrs, cph_urti_combined_incdt_during_pandemic_hrs, cph_urti_combined_incdt_post_2nd_lockdown_hrs)
cph_urti_combined_prevl_hrs = data_process_hrs_betas(cph_urti_combined_prevl_hrs, cph_urti_combined_prevl_ab_type_hrs, cph_urti_combined_prevl_15_24_hrs, cph_urti_combined_prevl_25_34_hrs, cph_urti_combined_prevl_35_44_hrs, cph_urti_combined_prevl_45_54_hrs, cph_urti_combined_prevl_55_64_hrs, cph_urti_combined_prevl_65_74_hrs, cph_urti_combined_prevl_75_more_hrs, cph_urti_combined_prevl_males_hrs, cph_urti_combined_prevl_females_hrs, cph_urti_combined_prevl_prepandemic_hrs, cph_urti_combined_prevl_during_pandemic_hrs, cph_urti_combined_prevl_post_2nd_lockdown_hrs)

cph_uti_incdt_hrs = data_process_hrs_betas(cph_uti_incdt_hrs, cph_uti_incdt_ab_type_hrs, cph_uti_incdt_15_24_hrs, cph_uti_incdt_25_34_hrs, cph_uti_incdt_35_44_hrs, cph_uti_incdt_45_54_hrs, cph_uti_incdt_55_64_hrs, cph_uti_incdt_65_74_hrs, cph_uti_incdt_75_more_hrs, cph_uti_incdt_males_hrs, cph_uti_incdt_females_hrs, cph_uti_incdt_prepandemic_hrs, cph_uti_incdt_during_pandemic_hrs, cph_uti_incdt_post_2nd_lockdown_hrs)
cph_uti_prevl_hrs = data_process_hrs_betas(cph_uti_prevl_hrs, cph_uti_prevl_ab_type_hrs, cph_uti_prevl_15_24_hrs, cph_uti_prevl_25_34_hrs, cph_uti_prevl_35_44_hrs, cph_uti_prevl_45_54_hrs, cph_uti_prevl_55_64_hrs, cph_uti_prevl_65_74_hrs, cph_uti_prevl_75_more_hrs, cph_uti_prevl_males_hrs, cph_uti_prevl_females_hrs, cph_uti_prevl_prepandemic_hrs, cph_uti_prevl_during_pandemic_hrs, cph_uti_prevl_post_2nd_lockdown_hrs)

cph_sinusitis_incdt_hrs = data_process_hrs_betas(cph_sinusitis_incdt_hrs, cph_sinusitis_incdt_ab_type_hrs, cph_sinusitis_incdt_15_24_hrs, cph_sinusitis_incdt_25_34_hrs, cph_sinusitis_incdt_35_44_hrs, cph_sinusitis_incdt_45_54_hrs, cph_sinusitis_incdt_55_64_hrs, cph_sinusitis_incdt_65_74_hrs, cph_sinusitis_incdt_75_more_hrs, cph_sinusitis_incdt_males_hrs, cph_sinusitis_incdt_females_hrs, cph_sinusitis_incdt_prepandemic_hrs, cph_sinusitis_incdt_during_pandemic_hrs, cph_sinusitis_incdt_post_2nd_lockdown_hrs)
cph_sinusitis_prevl_hrs = data_process_hrs_betas(cph_sinusitis_prevl_hrs, cph_sinusitis_prevl_ab_type_hrs, cph_sinusitis_prevl_15_24_hrs, cph_sinusitis_prevl_25_34_hrs, cph_sinusitis_prevl_35_44_hrs, cph_sinusitis_prevl_45_54_hrs, cph_sinusitis_prevl_45_54_hrs, cph_sinusitis_prevl_45_54_hrs, cph_sinusitis_prevl_75_more_hrs, cph_sinusitis_prevl_males_hrs, cph_sinusitis_prevl_females_hrs, cph_sinusitis_prevl_females_hrs, cph_sinusitis_prevl_females_hrs, cph_sinusitis_prevl_females_hrs)

cph_otmedia_incdt_hrs = data_process_hrs_betas(cph_otmedia_incdt_hrs, cph_otmedia_incdt_ab_type_hrs, cph_otmedia_incdt_15_24_hrs, cph_otmedia_incdt_25_34_hrs, cph_otmedia_incdt_25_34_hrs, cph_otmedia_incdt_45_54_hrs, cph_otmedia_incdt_55_64_hrs, cph_otmedia_incdt_65_74_hrs, cph_otmedia_incdt_75_more_hrs, cph_otmedia_incdt_males_hrs, cph_otmedia_incdt_females_hrs, cph_otmedia_incdt_prepandemic_hrs, cph_otmedia_incdt_during_pandemic_hrs, cph_otmedia_incdt_post_2nd_lockdown_hrs)
cph_otmedia_prevl_hrs = data_process_hrs_betas(cph_otmedia_prevl_hrs, cph_otmedia_prevl_ab_type_hrs, cph_otmedia_prevl_ab_type_hrs, cph_otmedia_prevl_25_34_hrs, cph_otmedia_prevl_25_34_hrs, cph_otmedia_prevl_45_54_hrs, cph_otmedia_prevl_45_54_hrs, cph_otmedia_prevl_45_54_hrs, cph_otmedia_prevl_75_more_hrs, cph_otmedia_prevl_75_more_hrs, cph_otmedia_prevl_females_hrs, cph_otmedia_prevl_prepandemic_hrs, cph_otmedia_prevl_prepandemic_hrs, cph_otmedia_prevl_post_2nd_lockdown_hrs)

cph_ot_externa_incdt_hrs = data_process_hrs_betas(cph_ot_externa_incdt_hrs, cph_ot_externa_incdt_ab_type_hrs, cph_ot_externa_incdt_15_24_hrs, cph_ot_externa_incdt_25_34_hrs, cph_ot_externa_incdt_35_44_hrs, cph_ot_externa_incdt_45_54_hrs, cph_ot_externa_incdt_55_64_hrs, cph_ot_externa_incdt_65_74_hrs, cph_ot_externa_incdt_75_more_hrs, cph_ot_externa_incdt_males_hrs, cph_ot_externa_incdt_females_hrs, cph_ot_externa_incdt_prepandemic_hrs, cph_ot_externa_incdt_during_pandemic_hrs, cph_ot_externa_incdt_post_2nd_lockdown_hrs)
cph_ot_externa_prevl_hrs = data_process_hrs_betas(cph_ot_externa_prevl_hrs, cph_ot_externa_prevl_ab_type_hrs, cph_ot_externa_prevl_15_24_hrs, cph_ot_externa_prevl_25_34_hrs, cph_ot_externa_prevl_35_44_hrs, cph_ot_externa_prevl_45_54_hrs, cph_ot_externa_prevl_55_64_hrs, cph_ot_externa_prevl_55_64_hrs, cph_ot_externa_prevl_75_more_hrs, cph_ot_externa_prevl_males_hrs, cph_ot_externa_prevl_females_hrs, cph_ot_externa_prevl_prepandemic_hrs, cph_ot_externa_prevl_during_pandemic_hrs, cph_ot_externa_prevl_post_2nd_lockdown_hrs)

cph_pneumonia_incdt_hrs = data_process_hrs_betas(cph_pneumonia_incdt_hrs, cph_pneumonia_incdt_ab_type_hrs, cph_pneumonia_incdt_15_24_hrs, cph_pneumonia_incdt_25_34_hrs, cph_pneumonia_incdt_35_44_hrs, cph_pneumonia_incdt_45_54_hrs, cph_pneumonia_incdt_55_64_hrs, cph_pneumonia_incdt_65_74_hrs, cph_pneumonia_incdt_75_more_hrs, cph_pneumonia_incdt_males_hrs, cph_pneumonia_incdt_females_hrs, cph_pneumonia_incdt_prepandemic_hrs, cph_pneumonia_incdt_during_pandemic_hrs, cph_pneumonia_incdt_post_2nd_lockdown_hrs)
cph_pneumonia_prevl_hrs = data_process_hrs_betas(cph_pneumonia_prevl_hrs, cph_pneumonia_prevl_ab_type_hrs, cph_pneumonia_prevl_ab_type_hrs, cph_pneumonia_prevl_ab_type_hrs, cph_pneumonia_prevl_ab_type_hrs, cph_pneumonia_prevl_45_54_hrs, cph_pneumonia_prevl_55_64_hrs, cph_pneumonia_prevl_55_64_hrs, cph_pneumonia_prevl_75_more_hrs, cph_pneumonia_prevl_males_hrs, cph_pneumonia_prevl_females_hrs, cph_pneumonia_prevl_prepandemic_hrs, cph_pneumonia_prevl_prepandemic_hrs, cph_pneumonia_prevl_post_2nd_lockdown_hrs)

cph_urti_incdt_hrs = data_process_hrs_betas(cph_urti_incdt_hrs, cph_urti_incdt_ab_type_hrs, cph_urti_incdt_15_24_hrs, cph_urti_incdt_25_34_hrs, cph_urti_incdt_35_44_hrs, cph_urti_incdt_45_54_hrs, cph_urti_incdt_55_64_hrs, cph_urti_incdt_65_74_hrs, cph_urti_incdt_75_more_hrs, cph_urti_incdt_males_hrs, cph_urti_incdt_females_hrs, cph_urti_incdt_prepandemic_hrs, cph_urti_incdt_during_pandemic_hrs, cph_urti_incdt_post_2nd_lockdown_hrs)
cph_urti_prevl_hrs = data_process_hrs_betas(cph_urti_prevl_hrs, cph_urti_prevl_ab_type_hrs, cph_urti_prevl_25_34_hrs, cph_urti_prevl_45_54_hrs, cph_urti_prevl_55_64_hrs, cph_urti_prevl_65_74_hrs, cph_urti_prevl_75_more_hrs, cph_urti_prevl_males_hrs, cph_urti_prevl_females_hrs, cph_urti_prevl_prepandemic_hrs, cph_urti_prevl_during_pandemic_hrs, cph_urti_prevl_post_2nd_lockdown_hrs)

cph_cough_incdt_hrs = data_process_hrs_betas(cph_cough_incdt_hrs, cph_cough_incdt_ab_type_hrs, cph_cough_incdt_15_24_hrs, cph_cough_incdt_25_34_hrs, cph_cough_incdt_35_44_hrs, cph_cough_incdt_45_54_hrs, cph_cough_incdt_55_64_hrs, cph_cough_incdt_65_74_hrs, cph_cough_incdt_75_more_hrs, cph_cough_incdt_males_hrs, cph_cough_incdt_females_hrs, cph_cough_incdt_prepandemic_hrs, cph_cough_incdt_during_pandemic_hrs, cph_cough_incdt_post_2nd_lockdown_hrs)
cph_cough_prevl_hrs = data_process_hrs_betas(cph_cough_prevl_hrs, cph_cough_prevl_ab_type_hrs, cph_cough_prevl_15_24_hrs, cph_cough_prevl_25_34_hrs, cph_cough_prevl_35_44_hrs, cph_cough_prevl_45_54_hrs, cph_cough_prevl_45_54_hrs, cph_cough_prevl_65_74_hrs, cph_cough_prevl_75_more_hrs, cph_cough_prevl_males_hrs, cph_cough_prevl_females_hrs, cph_cough_prevl_prepandemic_hrs, cph_cough_prevl_during_pandemic_hrs, cph_cough_prevl_post_2nd_lockdown_hrs)

cph_cough_cold_incdt_hrs = data_process_hrs_betas(cph_cough_cold_incdt_hrs, cph_cough_cold_incdt_ab_type_hrs, cph_cough_cold_incdt_15_24_hrs, cph_cough_cold_incdt_25_34_hrs, cph_cough_cold_incdt_35_44_hrs, cph_cough_cold_incdt_45_54_hrs, cph_cough_cold_incdt_55_64_hrs, cph_cough_cold_incdt_65_74_hrs, cph_cough_cold_incdt_75_more_hrs, cph_cough_cold_incdt_males_hrs, cph_cough_cold_incdt_females_hrs, cph_cough_cold_incdt_prepandemic_hrs, cph_cough_cold_incdt_during_pandemic_hrs, cph_cough_cold_incdt_post_2nd_lockdown_hrs)
cph_cough_cold_prevl_hrs = data_process_hrs_betas(cph_cough_cold_prevl_hrs, cph_cough_cold_prevl_ab_type_hrs, cph_cough_cold_prevl_15_24_hrs, cph_cough_cold_prevl_25_34_hrs, cph_cough_cold_prevl_35_44_hrs, cph_cough_cold_prevl_45_54_hrs, cph_cough_cold_prevl_55_64_hrs, cph_cough_cold_prevl_65_74_hrs, cph_cough_cold_prevl_75_more_hrs, cph_cough_cold_prevl_males_hrs, cph_cough_cold_prevl_females_hrs, cph_cough_cold_prevl_prepandemic_hrs, cph_cough_cold_prevl_during_pandemic_hrs, cph_cough_cold_prevl_post_2nd_lockdown_hrs)

cph_throat_incdt_hrs = data_process_hrs_betas(cph_throat_incdt_hrs, cph_throat_incdt_ab_type_hrs, cph_throat_incdt_15_24_hrs, cph_throat_incdt_25_34_hrs, cph_throat_incdt_35_44_hrs, cph_throat_incdt_45_54_hrs, cph_throat_incdt_55_64_hrs, cph_throat_incdt_65_74_hrs, cph_throat_incdt_75_more_hrs, cph_throat_incdt_males_hrs, cph_throat_incdt_females_hrs, cph_throat_incdt_prepandemic_hrs, cph_throat_incdt_during_pandemic_hrs, cph_throat_incdt_post_2nd_lockdown_hrs)
cph_throat_prevl_hrs = data_process_hrs_betas(cph_throat_prevl_hrs, cph_throat_prevl_ab_type_hrs, cph_throat_prevl_15_24_hrs, cph_throat_prevl_25_34_hrs, cph_throat_prevl_35_44_hrs, cph_throat_prevl_45_54_hrs, cph_throat_prevl_55_64_hrs, cph_throat_prevl_65_74_hrs, cph_throat_prevl_75_more_hrs, cph_throat_prevl_males_hrs, cph_throat_prevl_females_hrs, cph_throat_prevl_prepandemic_hrs, cph_throat_prevl_during_pandemic_hrs, cph_throat_prevl_post_2nd_lockdown_hrs)

# %%
d = {'variable': cph_lrti_incdt_hrs['variable'],
     
     'lrti_incdt': cph_lrti_incdt_hrs['betas'],
     'lrti_prevl': cph_lrti_prevl_hrs['betas'],
     
     'urti_combined_incdt': cph_urti_combined_incdt_hrs['betas'], 
     'urti_combined_prevl': cph_urti_combined_prevl_hrs['betas'],
     
     'uti_incdt': cph_uti_incdt_hrs['betas'], 
     'uti_prevl': cph_uti_prevl_hrs['betas'],
     
     'sinusitis_incdt': cph_sinusitis_incdt_hrs['betas'], 
     'sinusitis_prevl': cph_sinusitis_prevl_hrs['betas'], 
     
     'otmedia_incdt': cph_otmedia_incdt_hrs['betas'], 
     'otmedia_prevl': cph_otmedia_prevl_hrs['betas'],
     
     'ot_externa_incdt': cph_ot_externa_incdt_hrs['betas'], 
     'ot_externa_prevl': cph_ot_externa_prevl_hrs['betas'],

     'urti_incdt': cph_urti_incdt_hrs['betas'], 
     'urti_prevl': cph_urti_prevl_hrs['betas'],

     'pneumonia_incdt': cph_pneumonia_incdt_hrs['betas'], 
     'pneumonia_prevl': cph_pneumonia_prevl_hrs['betas'],

     'cough_incdt': cph_cough_incdt_hrs['betas'], 
     'cough_prevl': cph_cough_prevl_hrs['betas'],
     
     'cough_cold_incdt': cph_cough_cold_incdt_hrs['betas'], 
     'cough_cold_prevl': cph_cough_cold_prevl_hrs['betas'],

     'throat_incdt': cph_throat_incdt_hrs['betas'], 
     'throat_prevl': cph_throat_prevl_hrs['betas'],
    }
data = pd.DataFrame(data=d)

#replace 
data['variable'] = data['variable'].str.replace('lrti_ab_date', 'ab')

#remove HRs that their models did not converge
data.loc[data['variable'] == 'ab_55_64', 'sinusitis_prevl'] = "-" #cph_sinusitis_prevl_ab_55_64_1
data.loc[data['variable'] == 'ab_65_74', 'sinusitis_prevl'] = "-" #cph_sinusitis_prevl_ab_65_74_1
data.loc[data['variable'] == 'ab_prepandemic', 'sinusitis_prevl'] = "-" #cph_sinusitis_prevl_ab_prepandemic_1
data.loc[data['variable'] == 'ab_during_pandemic', 'sinusitis_prevl'] = "-" #cph_sinusitis_prevl_ab_during_pandemic_1
data.loc[data['variable'] == 'ab_post_2nd_lockdown', 'sinusitis_prevl'] = "-" #cph_sinusitis_prevl_ab_post_2nd_lockdown_1

data.loc[data['variable'] == 'ab_male', 'otmedia_prevl'] = "-" #cph_otmedia_prevl_males_hrs
data.loc[data['variable'] == 'ab_15_24', 'otmedia_prevl'] = "-" #cph_otmedia_prevl_ab_15_24_1
data.loc[data['variable'] == 'ab_35_44', 'otmedia_prevl'] = "-" #cph_otmedia_prevl_ab_35_44_1
data.loc[data['variable'] == 'ab_55_64', 'otmedia_prevl'] = "-" #cph_otmedia_prevl_ab_55_64_1
data.loc[data['variable'] == 'ab_65_74', 'otmedia_prevl'] = "-" #cph_otmedia_prevl_ab_65_74_1
data.loc[data['variable'] == 'ab_during_pandemic', 'otmedia_prevl'] = "-" #cph_otmedia_prevl_ab_during_pandemic_1

data.loc[data['variable'] == 'ab_65_74', 'otmedia_prevl'] = "-" #cph_ot_externa_prevl_ab_65_74_1

data.loc[data['variable'] == 'ab_15_24', 'pneumonia_prevl'] = "-" #cph_pneumonia_prevl_ab_15_24_1
data.loc[data['variable'] == 'ab_25_34', 'pneumonia_prevl'] = "-" #cph_pneumonia_prevl_ab_25_34_1
data.loc[data['variable'] == 'ab_35_44', 'pneumonia_prevl'] = "-" #cph_pneumonia_prevl_ab_35_44_1
data.loc[data['variable'] == 'ab_65_74', 'pneumonia_prevl'] = "-" #cph_pneumonia_prevl_ab_65_74_1
data.loc[data['variable'] == 'ab_during_pandemic', 'pneumonia_prevl'] = "-" #cph_pneumonia_prevl_ab_during_pandemic_1

data.loc[data['variable'] == 'ab_55_64', 'cough_prevl'] = "-" #cph_cough_prevl_ab_55_64_1

#print output in csv
data.to_csv(f'../output/aggregate_hrs_betas/cph_hrs_ab_all_infections.csv', index=False)
data
# Out:
#                    variable         lrti_incdt                     lrti_prevl  \
# 0                        ab   1.27 (0.04-0.44)              1.05 (-0.58-0.68)
# 1   ab_type_cat_Doxycycline  1.12 (-1.49-1.71)        1.04 (-7277.33-7277.41)
# 2            ab_type_cat_no  0.90 (-0.91-0.70)  2586429.41 (-3767.96-3797.49)
# 3         ab_type_cat_other  1.15 (-0.69-0.96)  2993296.75 (-3767.81-3797.64)
# 4                  ab_15_24  0.67 (-1.09-0.27)      0.00 (-13866.13-13830.58)
# 5                  ab_25_34  1.24 (-0.31-0.74)              2.05 (-0.51-1.94)
# 6                  ab_35_44  1.23 (-0.35-0.76)              0.80 (-1.70-1.25)
# 7                  ab_45_54   1.86 (0.15-1.09)      0.00 (-13919.16-13883.09)
# 8                  ab_55_64  1.25 (-0.29-0.73)      0.00 (-18076.39-18039.54)
# 9                  ab_65_74  0.92 (-0.71-0.53)              1.69 (-1.12-2.17)
# 10               ab_75_more  1.62 (-0.02-0.98)              1.64 (-1.05-2.04)
# ...
