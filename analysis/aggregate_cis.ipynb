# %% [markdown]
# # Aggregate Outputs of Cox Models for All Infections

# %%
import pandas as pd
import numpy as np

# %%
#read concordance index of models
output_lrti_incdt = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cis_lrti_incdt.csv', index_col=0)
output_lrti_incdt.index = ['lrti_incdt']
output_lrti_prevl = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cis_lrti_prevl.csv', index_col=0)
output_lrti_prevl.index = ['lrti_prevl']

output_urti_combined_incdt = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cis_urti_combined_incdt.csv', index_col=0)
output_urti_combined_incdt.index = ['urti_combined_incdt']
output_urti_combined_prevl = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cis_urti_combined_prevl.csv', index_col=0)
output_urti_combined_prevl.index = ['urti_combined_prevl']

output_uti_incdt = pd.read_csv(f'../output/hospitalisation_prediction_uti/cis_uti_incdt.csv', index_col=0)
output_uti_incdt.index = ['uti_incdt']
output_uti_prevl = pd.read_csv(f'../output/hospitalisation_prediction_uti/cis_uti_prevl.csv', index_col=0)
output_uti_prevl.index = ['uti_prevl']

output_sinusitis_incdt = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cis_sinusitis_incdt.csv', index_col=0)
output_sinusitis_incdt.index = ['sinusitis_incdt']
output_sinusitis_prevl = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cis_sinusitis_prevl.csv', index_col=0)
output_sinusitis_prevl.index = ['sinusitis_prevl']

output_otmedia_incdt = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cis_otmedia_incdt.csv', index_col=0)
output_otmedia_incdt.index = ['otmedia_incdt']
output_otmedia_prevl = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cis_otmedia_prevl.csv', index_col=0)
output_otmedia_prevl.index = ['otmedia_prevl']

output_ot_externa_incdt = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cis_ot_externa_incdt.csv', index_col=0)
output_ot_externa_incdt.index = ['ot_externa_incdt']
output_ot_externa_prevl = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cis_ot_externa_prevl.csv', index_col=0)
output_ot_externa_prevl.index = ['ot_externa_prevl']

output_urti_incdt = pd.read_csv(f'../output/hospitalisation_prediction_urti/cis_urti_incdt.csv', index_col=0)
output_urti_incdt.index = ['urti_incdt']
output_urti_prevl = pd.read_csv(f'../output/hospitalisation_prediction_urti/cis_urti_prevl.csv', index_col=0)
output_urti_prevl.index = ['urti_prevl']

output_cough_incdt = pd.read_csv(f'../output/hospitalisation_prediction_cough/cis_cough_incdt.csv', index_col=0)
output_cough_incdt.index = ['cough_incdt']
output_cough_prevl = pd.read_csv(f'../output/hospitalisation_prediction_cough/cis_cough_prevl.csv', index_col=0)
output_cough_prevl.index = ['cough_prevl']

output_cough_cold_incdt = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cis_cough_cold_incdt.csv', index_col=0)
output_cough_cold_incdt.index = ['cough_cold_incdt']
output_cough_cold_prevl = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cis_cough_cold_prevl.csv', index_col=0)
output_cough_cold_prevl.index = ['cough_cold_prevl']

output_throat_incdt = pd.read_csv(f'../output/hospitalisation_prediction_throat/cis_throat_incdt.csv', index_col=0)
output_throat_incdt.index = ['throat_incdt']
output_throat_prevl = pd.read_csv(f'../output/hospitalisation_prediction_throat/cis_throat_prevl.csv', index_col=0)
output_throat_prevl.index = ['throat_prevl']

# %%
# output_throat_prevl.index = ['throat_prevl']
output_throat_prevl
# Out:
#               ci_dev_lr  ci_val_lr  ci_dev_rf  ci_val_rf
# throat_prevl   0.744226   0.772323   0.744226   0.772323

# %%
output_urti_combined_prevl
# Out:
#                      ci_dev_lr  ci_val_lr  ci_dev_rf  ci_val_rf
# urti_combined_prevl   0.693071    0.68459   0.693071    0.68459

# %%
#concat all cis
outputs_all = pd.concat([output_lrti_incdt, output_lrti_prevl, output_urti_combined_incdt, output_urti_combined_prevl, output_uti_incdt, output_uti_prevl, output_sinusitis_incdt, output_sinusitis_prevl, output_otmedia_incdt, output_otmedia_prevl, output_ot_externa_incdt, output_ot_externa_prevl, output_urti_incdt, output_urti_prevl, output_cough_incdt, output_cough_prevl, output_cough_cold_incdt, output_cough_cold_prevl, output_throat_incdt, output_throat_prevl])
#save 
outputs_all.to_csv(f'../output/aggregate_cis/cox_output_infections.csv', index=False)
outputs_all
# Out:
#                      ci_dev_lr  ci_val_lr  ci_dev_rf  ci_val_rf
# lrti_incdt            0.634567   0.636385   0.634567   0.636385
# lrti_prevl            0.651264   0.657044   0.651259   0.659468
# urti_combined_incdt   0.692478   0.691571   0.692478   0.691571
# urti_combined_prevl   0.693071   0.684590   0.693071   0.684590
# uti_incdt             0.618566   0.614589   0.618566   0.614589
# uti_prevl             0.624223   0.598854   0.624223   0.598854
# sinusitis_incdt       0.561406   0.557646   0.561406   0.557646
# sinusitis_prevl       0.582007   0.570813   0.582007   0.570813
# otmedia_incdt         0.540278   0.545268   0.540278   0.545268
# otmedia_prevl         0.555254   0.534206   0.555254   0.534206
# ot_externa_incdt      0.517148   0.511071   0.517148   0.511071
# ot_externa_prevl      0.526070   0.514363   0.526070   0.512277
# urti_incdt            0.553017   0.550393   0.553017   0.550393
# urti_prevl            0.562298   0.543643   0.562298   0.541892
# ...
