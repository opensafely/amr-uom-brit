# %% [markdown]
# # Aggregate Outputs of Cox Models for All Infections

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
warnings.warn('DelftStack')
warnings.warn('Do not show this message')

# %%
#read concordance index of models with validation datasets
output_lrti_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_no_abs_incdt_output.txt', delimiter = "\t")
output_lrti_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_no_abs_prevl_output.txt', delimiter = "\t")
output_lrti_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_abs_incdt_output.txt', delimiter = "\t")
output_lrti_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_lrti/cph_lrti_abs_prevl_output.txt', delimiter = "\t")

output_urti_combined_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_no_abs_incdt_output.txt', delimiter = "\t")
output_urti_combined_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_no_abs_prevl_output.txt', delimiter = "\t")
output_urti_combined_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_abs_incdt_output.txt', delimiter = "\t")
output_urti_combined_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_abs_prevl_output.txt', delimiter = "\t")

output_uti_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_no_abs_incdt_output.txt', delimiter = "\t")
output_uti_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_no_abs_prevl_output.txt', delimiter = "\t")
output_uti_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_abs_incdt_output.txt', delimiter = "\t")
output_uti_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_uti/cph_uti_abs_prevl_output.txt', delimiter = "\t")

output_sinusitis_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_no_abs_incdt_output.txt', delimiter = "\t")
# output_sinusitis_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_no_abs_prevl_output.txt', delimiter = "\t")
output_sinusitis_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_abs_incdt_output.txt', delimiter = "\t")
# output_sinusitis_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_abs_prevl_output.txt', delimiter = "\t")

output_otmedia_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_no_abs_incdt_output.txt', delimiter = "\t")
output_otmedia_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_no_abs_prevl_output.txt', delimiter = "\t")
output_otmedia_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_abs_incdt_output.txt', delimiter = "\t")
output_otmedia_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_abs_prevl_output.txt', delimiter = "\t")

output_ot_externa_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_no_abs_incdt_output.txt', delimiter = "\t")
output_ot_externa_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_no_abs_prevl_output.txt', delimiter = "\t")
output_ot_externa_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_abs_incdt_output.txt', delimiter = "\t")
# output_ot_externa_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_abs_prevl_output.txt', delimiter = "\t")

output_pneumonia_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_no_abs_incdt_output.txt', delimiter = "\t")
output_pneumonia_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_no_abs_prevl_output.txt', delimiter = "\t")
output_pneumonia_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_abs_incdt_output.txt', delimiter = "\t")
# output_pneumonia_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_abs_prevl_output.txt', delimiter = "\t")

output_urti_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_no_abs_incdt_output.txt', delimiter = "\t")
output_urti_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_no_abs_prevl_output.txt', delimiter = "\t")
output_urti_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_abs_incdt_output.txt', delimiter = "\t")
output_urti_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_urti/cph_urti_abs_prevl_output.txt', delimiter = "\t")

output_cough_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_no_abs_incdt_output.txt', delimiter = "\t")
output_cough_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_no_abs_prevl_output.txt', delimiter = "\t")
output_cough_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_abs_incdt_output.txt', delimiter = "\t")
output_cough_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_cough/cph_cough_abs_prevl_output.txt', delimiter = "\t")

output_cough_cold_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_no_abs_incdt_output.txt', delimiter = "\t")
output_cough_cold_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_no_abs_prevl_output.txt', delimiter = "\t")
output_cough_cold_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_abs_incdt_output.txt', delimiter = "\t")
output_cough_cold_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_abs_prevl_output.txt', delimiter = "\t")

output_throat_no_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_no_abs_incdt_output.txt', delimiter = "\t")
output_throat_no_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_no_abs_prevl_output.txt', delimiter = "\t")
output_throat_abs_incdt = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_abs_incdt_output.txt', delimiter = "\t")
output_throat_abs_prevl = pd.read_csv(f'../output/hospitalisation_prediction_throat/cph_throat_abs_prevl_output.txt', delimiter = "\t")

# %%
#read concordance index of models with development datastes from html summary files of eahc Cox model
cph_lrti_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_no_abs_incdt_summary.html')
cph_lrti_no_abs_incdt_2 = cph_lrti_no_abs_incdt[2]
cph_lrti_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_no_abs_prevl_summary.html')
cph_lrti_no_abs_prevl_2 = cph_lrti_no_abs_prevl[2]
cph_lrti_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_abs_incdt_summary.html')
cph_lrti_abs_incdt_2 = cph_lrti_abs_incdt[2]
cph_lrti_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_lrti/cph_lrti_abs_prevl_summary.html')
cph_lrti_abs_prevl_2 = cph_lrti_abs_prevl[2]

cph_urti_combined_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_no_abs_incdt_summary.html')
cph_urti_combined_no_abs_incdt_2 = cph_urti_combined_no_abs_incdt[2]
cph_urti_combined_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_no_abs_prevl_summary.html')
cph_urti_combined_no_abs_prevl_2 = cph_urti_combined_no_abs_prevl[2]
cph_urti_combined_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_abs_incdt_summary.html')
cph_urti_combined_abs_incdt_2 = cph_urti_combined_abs_incdt[2]
cph_urti_combined_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_urti_combined/cph_urti_combined_abs_prevl_summary.html')
cph_urti_combined_abs_prevl_2 = cph_urti_combined_abs_prevl[2]

cph_uti_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_no_abs_incdt_summary.html')
cph_uti_no_abs_incdt_2 = cph_uti_no_abs_incdt[2]
cph_uti_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_no_abs_prevl_summary.html')
cph_uti_no_abs_prevl_2 = cph_uti_no_abs_prevl[2]
cph_uti_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_abs_incdt_summary.html')
cph_uti_abs_incdt_2 = cph_uti_abs_incdt[2]
cph_uti_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_uti/cph_uti_abs_prevl_summary.html')
cph_uti_abs_prevl_2 = cph_uti_abs_prevl[2]

cph_sinusitis_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_no_abs_incdt_summary.html')
cph_sinusitis_no_abs_incdt_2 = cph_sinusitis_no_abs_incdt[2]
# cph_sinusitis_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_no_abs_prevl_summary.html')
# cph_sinusitis_no_abs_prevl_2 = cph_sinusitis_no_abs_prevl[2]
cph_sinusitis_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_abs_incdt_summary.html')
cph_sinusitis_abs_incdt_2 = cph_sinusitis_abs_incdt[2]
# cph_sinusitis_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_sinusitis/cph_sinusitis_abs_prevl_summary.html')
# cph_sinusitis_abs_prevl_2 = cph_sinusitis_abs_prevl[2]

cph_otmedia_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_no_abs_incdt_summary.html')
cph_otmedia_no_abs_incdt_2 = cph_otmedia_no_abs_incdt[2]
cph_otmedia_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_no_abs_prevl_summary.html')
cph_otmedia_no_abs_prevl_2 = cph_otmedia_no_abs_prevl[2]
cph_otmedia_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_abs_incdt_summary.html')
cph_otmedia_abs_incdt_2 = cph_otmedia_abs_incdt[2]
cph_otmedia_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_otmedia/cph_otmedia_abs_prevl_summary.html')
cph_otmedia_abs_prevl_2 = cph_otmedia_abs_prevl[2]

cph_ot_externa_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_no_abs_incdt_summary.html')
cph_ot_externa_no_abs_incdt_2 = cph_ot_externa_no_abs_incdt[2]
cph_ot_externa_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_no_abs_prevl_summary.html')
cph_ot_externa_no_abs_prevl_2 = cph_ot_externa_no_abs_prevl[2]
cph_ot_externa_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_abs_incdt_summary.html')
cph_ot_externa_abs_incdt_2 = cph_ot_externa_abs_incdt[2]
# cph_ot_externa_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_ot_externa/cph_ot_externa_abs_prevl_summary.html')
# cph_ot_externa_abs_prevl_2 = cph_ot_externa_abs_prevl[2]

cph_pneumonia_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_no_abs_incdt_summary.html')
cph_pneumonia_no_abs_incdt_2 = cph_pneumonia_no_abs_incdt[2]
cph_pneumonia_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_no_abs_prevl_summary.html')
cph_pneumonia_no_abs_prevl_2 = cph_pneumonia_no_abs_prevl[2]
cph_pneumonia_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_abs_incdt_summary.html')
cph_pneumonia_abs_incdt_2 = cph_pneumonia_abs_incdt[2]
cph_pneumonia_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_pneumonia/cph_pneumonia_abs_prevl_summary.html')
cph_pneumonia_abs_prevl_2 = cph_pneumonia_abs_prevl[2]

cph_urti_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_no_abs_incdt_summary.html')
cph_urti_no_abs_incdt_2 = cph_urti_no_abs_incdt[2]
cph_urti_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_no_abs_prevl_summary.html')
cph_urti_no_abs_prevl_2 = cph_urti_no_abs_prevl[2]
cph_urti_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_abs_incdt_summary.html')
cph_urti_abs_incdt_2 = cph_urti_abs_incdt[2]
cph_urti_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_urti/cph_urti_abs_prevl_summary.html')
cph_urti_abs_prevl_2 = cph_urti_abs_prevl[2]

cph_cough_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_no_abs_incdt_summary.html')
cph_cough_no_abs_incdt_2 = cph_cough_no_abs_incdt[2]
cph_cough_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_no_abs_prevl_summary.html')
cph_cough_no_abs_prevl_2 = cph_cough_no_abs_prevl[2]
cph_cough_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_abs_incdt_summary.html')
cph_cough_abs_incdt_2 = cph_cough_abs_incdt[2]
cph_cough_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_cough/cph_cough_abs_prevl_summary.html')
cph_cough_abs_prevl_2 = cph_cough_abs_prevl[2]

cph_cough_cold_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_no_abs_incdt_summary.html')
cph_cough_cold_no_abs_incdt_2 = cph_cough_cold_no_abs_incdt[2]
cph_cough_cold_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_no_abs_prevl_summary.html')
cph_cough_cold_no_abs_prevl_2 = cph_cough_cold_no_abs_prevl[2]
cph_cough_cold_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_abs_incdt_summary.html')
cph_cough_cold_abs_incdt_2 = cph_cough_cold_abs_incdt[2]
cph_cough_cold_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_cough_cold/cph_cough_cold_abs_prevl_summary.html')
cph_cough_cold_abs_prevl_2 = cph_cough_cold_abs_prevl[2]

cph_throat_no_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_no_abs_incdt_summary.html')
cph_throat_no_abs_incdt_2 = cph_throat_no_abs_incdt[2]
cph_throat_no_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_no_abs_prevl_summary.html')
cph_throat_no_abs_prevl_2 = cph_throat_no_abs_prevl[2]
cph_throat_abs_incdt = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_abs_incdt_summary.html')
cph_throat_abs_incdt_2 = cph_throat_abs_incdt[2]
cph_throat_abs_prevl = pd.read_html(f'../output/hospitalisation_prediction_throat/cph_throat_abs_prevl_summary.html')
cph_throat_abs_prevl_2 = cph_throat_abs_prevl[2]

# %%
d = {'variable1': [cph_lrti_no_abs_incdt_2[1][0], cph_urti_combined_no_abs_incdt_2[1][0], 
                   cph_uti_no_abs_incdt_2[1][0], cph_sinusitis_no_abs_incdt_2[1][0],
                   cph_otmedia_no_abs_incdt_2[1][0], cph_ot_externa_no_abs_incdt_2[1][0],
                   cph_pneumonia_no_abs_incdt_2[1][0], cph_urti_no_abs_incdt_2[1][0], 
                   cph_cough_no_abs_incdt_2[1][0], cph_cough_cold_no_abs_incdt_2[1][0],
                   cph_throat_no_abs_incdt_2[1][0],

                   cph_lrti_no_abs_prevl_2[1][0], cph_urti_combined_no_abs_prevl_2[1][0], 
                   cph_uti_no_abs_prevl_2[1][0], #cph_sinusitis_no_abs_prevl_2[1][0],
                   cph_otmedia_no_abs_prevl_2[1][0], cph_ot_externa_no_abs_prevl_2[1][0],
                   cph_pneumonia_no_abs_prevl_2[1][0], cph_urti_no_abs_prevl_2[1][0], 
                   cph_cough_no_abs_prevl_2[1][0], cph_cough_cold_no_abs_prevl_2[1][0],
                   cph_throat_no_abs_prevl_2[1][0],

                   cph_lrti_abs_incdt_2[1][0], cph_urti_combined_abs_incdt_2[1][0], 
                   cph_uti_abs_incdt_2[1][0], cph_sinusitis_abs_incdt_2[1][0],
                   cph_otmedia_abs_incdt_2[1][0], cph_ot_externa_abs_incdt_2[1][0],
                   cph_pneumonia_abs_incdt_2[1][0], cph_urti_abs_incdt_2[1][0], 
                   cph_cough_abs_incdt_2[1][0], cph_cough_cold_abs_incdt_2[1][0],
                   cph_throat_abs_incdt_2[1][0],

                   cph_lrti_abs_prevl_2[1][0], cph_urti_combined_abs_prevl_2[1][0], 
                   cph_uti_abs_prevl_2[1][0], #cph_sinusitis_abs_prevl_2[1][0],
                   cph_otmedia_abs_prevl_2[1][0], #cph_ot_externa_abs_prevl_2[1][0],
                   cph_pneumonia_abs_prevl_2[1][0], cph_urti_abs_prevl_2[1][0], 
                   cph_cough_abs_prevl_2[1][0], cph_cough_cold_abs_prevl_2[1][0],
                   cph_throat_abs_prevl_2[1][0],
                   ],
     'variable2': [output_lrti_no_abs_incdt.loc[0][0], output_urti_combined_no_abs_incdt.loc[0][0], 
                   output_uti_no_abs_incdt.loc[0][0], output_sinusitis_no_abs_incdt.loc[0][0],
                   output_otmedia_no_abs_incdt.loc[0][0], output_ot_externa_no_abs_incdt.loc[0][0],
                   output_pneumonia_no_abs_incdt.loc[0][0], output_urti_no_abs_incdt.loc[0][0],
                   output_cough_no_abs_incdt.loc[0][0], output_cough_cold_no_abs_incdt.loc[0][0], 
                   output_throat_no_abs_incdt.loc[0][0],

                   output_lrti_no_abs_prevl.loc[0][0], output_urti_combined_no_abs_prevl.loc[0][0], 
                   output_uti_no_abs_prevl.loc[0][0], #output_sinusitis_no_abs_prevl.loc[0][0],
                   output_otmedia_no_abs_prevl.loc[0][0], output_ot_externa_no_abs_prevl.loc[0][0],
                   output_pneumonia_no_abs_prevl.loc[0][0], output_urti_no_abs_prevl.loc[0][0],
                   output_cough_no_abs_prevl.loc[0][0], output_cough_cold_no_abs_prevl.loc[0][0], 
                   output_throat_no_abs_prevl.loc[0][0],

                   output_lrti_abs_incdt.loc[0][0], output_urti_combined_abs_incdt.loc[0][0], 
                   output_uti_abs_incdt.loc[0][0], output_sinusitis_abs_incdt.loc[0][0],
                   output_otmedia_abs_incdt.loc[0][0], output_ot_externa_abs_incdt.loc[0][0],
                   output_pneumonia_abs_incdt.loc[0][0], output_urti_abs_incdt.loc[0][0],
                   output_cough_abs_incdt.loc[0][0], output_cough_cold_abs_incdt.loc[0][0], 
                   output_throat_abs_incdt.loc[0][0],

                   output_lrti_abs_prevl.loc[0][0], output_urti_combined_abs_prevl.loc[0][0], 
                   output_uti_abs_prevl.loc[0][0], #output_sinusitis_abs_prevl.loc[0][0],
                   output_otmedia_abs_prevl.loc[0][0], #output_ot_externa_abs_prevl.loc[0][0],
                   'Concordance index for pneumonia_abs_prevl with validation data:0', #output_pneumonia_abs_prevl.loc[0][0], 
                   output_urti_abs_prevl.loc[0][0],
                   output_cough_abs_prevl.loc[0][0], output_cough_cold_abs_prevl.loc[0][0], 
                   output_throat_abs_prevl.loc[0][0],
                 ]
    }
data = pd.DataFrame(data=d)


# #keep concordance index and remove other letters, and shape dataframe similar to the table
data[['var2', 'ci2']] = data['variable2'].str.split(':', expand=True)
data = data.drop(columns=['variable2'])
data = data[['var2', 'variable1', 'ci2']]
data.columns = ['infection', 'ci_dev', 'ci_val']

#keep two decimal
data['ci_val'] = data['ci_val'].astype(float)
data['ci_val'] = np.round(data['ci_val'], decimals=2)

#remove 0.00 from ci_val column
for row in range(0, len(data)):
        if data['ci_val'][row] == 0.00:
           data['ci_val'][row] = '-'

# data['infection'] = data['infection'].str.split('with', expand=True)[0]
data['infection'] = data['infection'].str.replace('Concordance index for ', '')
data['infection'] = data['infection'].str.replace('with validation data', '')

data.to_csv(f'../output/aggregate_cox_cis/cox_output_infections.csv', index=False)
data
# Out:
#                       infection ci_dev ci_val
# 0            lrti_no_abs_incdt    0.57   0.49
# 1   urti_combined_no_abs_incdt    0.53    0.5
# 2             uti_no_abs_incdt    0.57   0.49
# 3       sinusitis_no_abs_incdt    0.58   0.47
# 4         otmedia_no_abs_incdt    0.57   0.49
# 5      ot_externa_no_abs_incdt    0.56   0.49
# 6       pneumonia_no_abs_incdt    0.58    0.5
# 7            urti_no_abs_incdt    0.55    0.5
# 8           cough_no_abs_incdt    0.59    0.5
# 9      cough_cold_no_abs_incdt    0.58   0.49
# 10         throat_no_abs_incdt    0.56    0.5
# 11           lrti_no_abs_prevl    0.72   0.46
# 12  urti_combined_no_abs_prevl    0.59   0.46
# 13            uti_no_abs_prevl    0.65   0.55
# 14        otmedia_no_abs_prevl    0.76   0.43
# 15     ot_externa_no_abs_prevl    0.75   0.37
# 16      pneumonia_no_abs_prevl    0.71   0.52
# 17           urti_no_abs_prevl    0.70   0.52
# 18          cough_no_abs_prevl    0.69    0.5
# ...
